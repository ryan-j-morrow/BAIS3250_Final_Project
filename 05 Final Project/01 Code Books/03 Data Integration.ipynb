# %% [markdown]
# # Scraping Capitol Trades

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd  # For handling data in DataFrame
from selenium import webdriver  # For controlling the web browser and interacting with HTML content
from selenium.webdriver.chrome.service import Service  # For setting up ChromeDriver as a service
from selenium.webdriver.common.by import By  # To locate HTML elements by XPath
from selenium.webdriver.chrome.options import Options  # For handling Chrome options
from webdriver_manager.chrome import ChromeDriverManager  # For automatic ChromeDriver installation
import time  # For handling wait times
import random  # For randomizing scroll and wait times
import os
import glob #finding all of the subset files

# %% [markdown]
# ### Set Up Paths

# %%
home_path = os.getcwd()
home_path = os.path.dirname(home_path)
home_path += "\\"

data_path = home_path + "02 Data Files\\"

folder_path = data_path + "02 Trade Scraping\\"

print(data_path)
# Out:
# c:\Users\rjrul\OneDrive - University of Iowa\00 Current Semester\01 BAIS 3250 - Data Wrangling\05 Final Project\02 Data Files\

# %% [markdown]
# ## Import Data and Combine Data

# %%
# Find all CSV files that start with "transaction_log_scraped_subset"
csv_files = glob.glob(os.path.join(folder_path, "transaction_log_scraped_subset*.csv"))

# Read and combine all CSV files into a single DataFrame
df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# %%
df
# Out:
#                          Name       Party Chamber State Ticker       Date  \
# 0      Marjorie Taylor Greene  Republican   House    GA    NaN  2025-3-19
# 1                Bill Keating    Democrat   House    MA    BAC   2025-3-5
# 2                Bill Keating    Democrat   House    MA     BJ   2025-3-2
# 3                Bill Keating    Democrat   House    MA     GS  2025-2-27
# 4                Bill Keating    Democrat   House    MA    JPM   2025-3-5
# ...                       ...         ...     ...   ...    ...        ...
# 34824               Ro Khanna    Democrat   House    CA   URBN   2024-2-4
# 34825               Ro Khanna    Democrat   House    CA     GM  2024-2-19
# 34826               Ro Khanna    Democrat   House    CA   ELAN  2024-2-21
# 34827               Ro Khanna    Democrat   House    CA    NaN   2024-2-1
# 34828               Ro Khanna    Democrat   House    CA     HD  2024-2-12
#
#          Buy   Sell
# 0       True  False
# 1       True  False
# 2      False   True
# 3       True  False
# 4       True  False
# ...      ...    ...
# 34824  False   True
# 34825  False   True
# 34826  False   True
# 34827  False   True
# 34828   True  False
#
# [34829 rows x 8 columns]

# %% [markdown]
# ## Clean Data

# %%
df["Date_As_DateTime"] = pd.to_datetime(df["Date"])

df = df[df["Date_As_DateTime"].dt.year.isin([2023, 2024])] #Filter to just 2023 and 2024

df
# Out:
#                  Name       Party Chamber State Ticker        Date    Buy  \
# 263         Neal Dunn  Republican   House    FL   MSTR  2024-12-23   True
# 951    Dave McCormick  Republican  Senate   NaN    NaN   2024-2-17   True
# 1212        Ro Khanna    Democrat   House    CA    LIN    2024-2-1  False
# 1213        Ro Khanna    Democrat   House    CA   PENN   2024-2-14   True
# 1214        Ro Khanna    Democrat   House    CA   PENN    2024-2-1   True
# ...               ...         ...     ...   ...    ...         ...    ...
# 34824       Ro Khanna    Democrat   House    CA   URBN    2024-2-4  False
# 34825       Ro Khanna    Democrat   House    CA     GM   2024-2-19  False
# 34826       Ro Khanna    Democrat   House    CA   ELAN   2024-2-21  False
# 34827       Ro Khanna    Democrat   House    CA    NaN    2024-2-1  False
# 34828       Ro Khanna    Democrat   House    CA     HD   2024-2-12   True
#
#         Sell Date_As_DateTime
# 263    False       2024-12-23
# 951    False       2024-02-17
# 1212    True       2024-02-01
# 1213   False       2024-02-14
# 1214   False       2024-02-01
# ...      ...              ...
# 34824   True       2024-02-04
# 34825   True       2024-02-19
# 34826   True       2024-02-21
# 34827   True       2024-02-01
# 34828  False       2024-02-12
#
# [21359 rows x 9 columns]

# %% [markdown]
# ### Cleaning Tickers

# %% [markdown]
# Import Ticker List

# %%
tickers = pd.read_csv(data_path+"01 Tickers\\"+"final_tickers.csv")

tickers = set(tickers["Ticker"])

tickers
# Out:
# {'SSBI',
#  'DHC',
#  'DHX',
#  'MTA',
#  'VCICW',
#  'CMCL',
#  'SLG',
#  'HUSA',
#  'OMI',
#  'MFM',
#  'CTSO',
#  'AS',
#  'FSBW',
#  'CMMB',
#  'UVV',
#  'NSSC',
#  'SWIN',
#  'IBM',
#  'AQN',
#  'DSWL',
#  'CDZIP',
#  'TNGX',
#  'APEI',
#  'GSBD',
#  'CEP',
#  'TDTH',
#  'GAM',
#  'PTVE',
#  'CJET',
#  'AMN',
#  'REBN',
#  'AVGO',
#  'COST',
#  'PAYO',
#  'GLBZ',
#  'FLIC',
#  'PECO',
#  'BOX',
#  'TPIC',
#  'PRCH',
#  'FULTP',
#  'FRSH',
#  'STHO',
#  'SLSR',
#  'STEW',
#  'TEM',
#  'FVR',
#  'RDFN',
#  'MTCH',
#  'PSA',
#  'DIS',
#  'TSQ',
#  'ABVE',
#  'LUCY',
#  'GEOS',
#  'ADVWW',
#  'DKS',
#  'CZWI',
#  'SPXX',
#  'ATMC',
#  'VOYA',
#  'VRDN',
#  'TW',
#  'DXCM',
#  'VCIC',
#  'NAN',
#  'BFRGW',
#  'MCD',
#  'BCAX',
#  'CLDX',
#  'ARQ',
#  'CVBF',
#  'MAYA',
#  'RGT',
#  'LOT',
#  'LVRO',
#  'RXT',
#  'EOT',
#  'VC',
#  'BOLD',
#  'HTOO',
#  'PFIS',
#  'MTR',
#  'OVID',
#  'SGHC',
#  'PENG',
#  'CHI',
#  'KNSA',
#  'OMH',
#  'PLAG',
#  'LUMN',
#  'I',
#  'UFG',
#  'IOBT',
#  'MYN',
#  'SGD',
#  'BELFA',
#  'QDEL',
#  'SCPH',
#  'HCKT',
#  'HOWL',
#  'BRN',
#  'AMBP',
#  'PACK',
#  'CRTO',
#  'SRFM',
#  'ISRLW',
#  'PWM',
#  'EVTC',
#  'SLGL',
#  'BNRG',
#  'ENTO',
#  'CPS',
#  'IBN',
#  'AIRG',
#  'KMB',
#  'EOS',
#  'RTC',
#  'CLSD',
#  'SPHL',
#  'EEIQ',
#  'IGI',
#  'GBLI',
#  'PSBD',
#  'AGNCL',
#  'PDM',
#  'SSL',
#  'XOS',
#  'IRT',
#  'MSGM',
#  'CZR',
#  'TANH',
#  'AIMAW',
#  'LAZR',
#  'SUPV',
#  'NMTC',
#  'CMCM',
#  'NGL',
#  'PYPL',
#  'VCICU',
#  'LDTCW',
#  'NATH',
#  'FBRX',
#  'AKTX',
#  'HDB',
#  'MCVT',
#  'PSTG',
#  'BROG',
#  'LTRYW',
#  'CPT',
#  'ABTS',
#  'HE',
#  'HSCS',
#  'TPC',
#  'TDOC',
#  'MEDP',
#  'LSH',
#  'NAK',
#  'ACNT',
#  'APCX',
#  'BFST',
#  'FIS',
#  'ZENV',
#  'TRU',
#  'BPRN',
#  'CCG',
#  'OXM',
#  'BTT',
#  'LANV',
#  'BRKR',
#  'BLFS',
#  'VERI',
#  'ATHM',
#  'MRIN',
#  'PFD',
#  'SAFE',
#  'WBS',
#  'IBO',
#  'MAPSW',
#  'AXTA',
#  'NHPAP',
#  'BACK',
#  'USEG',
#  'CVKD',
#  'AHT',
#  'GBAB',
#  'VLO',
#  'NEGG',
#  'ONVO',
#  'REI',
#  'BCSF',
#  'ONMDW',
#  'CCEL',
#  'YOU',
#  'ATOM',
#  'BAOS',
#  'IPI',
#  'NAYA',
#  'CMTG',
#  'BG',
#  'PRU',
#  'NWS',
#  'MLP',
#  'OP',
#  'BML',
#  'NMM',
#  'AEG',
#  'TCI',
#  'STRO',
#  'SBFM',
#  'GRC',
#  'GATEW',
#  'PMVP',
#  'BFK',
#  'MSSAW',
#  'RCAT',
#  'ETR',
#  'ARBK',
#  'ERO',
#  'MNRO',
#  'MCB',
#  'ZTEK',
#  'BMEA',
#  'STAA',
#  'AMGN',
#  'GTBP',
#  'PAX',
#  'GJR',
#  'HTFC',
#  'SENS',
#  'FGN',
#  'NTRB',
#  'RKLB',
#  'THR',
#  'EVOK',
#  'TWLO',
#  'DHCNI',
#  'AZI',
#  'OCSL',
#  'STRL',
#  'OWLT',
#  'CCAP',
#  'APTO',
#  'CRSR',
#  'PLMKW',
#  'UAMY',
#  'ELSE',
#  'RCG',
#  'ANIX',
#  'HOFVW',
#  'OABI',
#  'PHM',
#  'EW',
#  'MAIN',
#  'EPM',
#  'BFRG',
#  'CXT',
#  'PLYM',
#  'CMRE',
#  'AAPL',
#  'MTW',
#  'SNCRL',
#  'SPB',
#  'GTLS',
#  'CLRO',
#  'OCGN',
#  'LEG',
#  'SRM',
#  'ALNT',
#  'PGP',
#  'CMPOW',
#  'NEOVW',
#  'BMRC',
#  'DRTS',
#  'PLNT',
#  'LRHC',
#  'SITE',
#  'TMCI',
#  'LUNR',
#  'PRE',
#  'IDR',
#  'MSCI',
#  'UBSI',
#  'USAS',
#  'CTBB',
#  'ANIP',
#  'SCCO',
#  'AEVAW',
#  'INVX',
#  'RF',
#  'PLSE',
#  'ARTV',
#  'FFBC',
#  'ASLE',
#  'ONC',
#  'STRT',
#  'LNZAW',
#  'RVLV',
#  'AUROW',
#  'RTO',
#  'KEX',
#  'LPLA',
#  'AVBP',
#  'MNDY',
#  'BMO',
#  'NRUC',
#  'BSM',
#  'EIC',
#  'QVCGB',
#  'CSCI',
#  'HBB',
#  'JFIN',
#  'NWL',
#  'KC',
#  'KRNY',
#  'SDA',
#  'AOMN',
#  'GNW',
#  'COOT',
#  'AVR',
#  'CNET',
#  'SLXNW',
#  'SGLY',
#  'PVH',
#  'ZTR',
#  'EOLS',
#  'SXTPW',
#  'VLYPP',
#  'FFIN',
#  'DBD',
#  'MOBX',
#  'NWPX',
#  'COMM',
#  'TALK',
#  'BE',
#  'SVT',
#  'NTWOW',
#  'GSL',
#  'TWNP',
#  'JBTM',
#  'MIY',
#  'GRO',
#  'VPG',
#  'TPR',
#  'PBH',
#  'WRBY',
#  'HPAIW',
#  'MTH',
#  'SEZL',
#  'NUW',
#  'FRSX',
#  'CEG',
#  'DGNX',
#  'INTC',
#  'AGNC',
#  'KELYA',
#  'AKBA',
#  'CERS',
#  'CLRC',
#  'NIO',
#  'SYK',
#  'ZIMV',
#  'ETO',
#  'PESI',
#  'OXSQZ',
#  'GGG',
#  'IKNA',
#  'FRT',
#  'KIM',
#  'CAC',
#  'RLJ',
#  'GCTS',
#  'SKYH',
#  'CALM',
#  'HSON',
#  'CMTL',
#  'CPRT',
#  'FRGE',
#  'AENT',
#  'PBF',
#  'TVGN',
#  'NTGR',
#  'GFF',
#  'LNSR',
#  'CRML',
#  'AUUD',
#  'RILY',
#  'EML',
#  'JCE',
#  'CAE',
#  'HPKEW',
#  'MOVE',
#  'AVTR',
#  'TTNP',
#  'ECF',
#  'EDRY',
#  'XWEL',
#  'SUI',
#  'BARK',
#  'GLO',
#  'MKTW',
#  'ACXP',
#  'VSEE',
#  'YOSH',
#  'CCOI',
#  'BANF',
#  'ZYBT',
#  'VNRX',
#  'NMFCZ',
#  'TWFG',
#  'COLA',
#  'BTX',
#  'CZFS',
#  'PHR',
#  'ASBA',
#  'HNW',
#  'MOGO',
#  'CRWD',
#  'ONBPP',
#  'REAX',
#  'PBR',
#  'XFLT',
#  'DB',
#  'BKH',
#  'HPAI',
#  'WKEY',
#  'YHNAU',
#  'GPOR',
#  'CNTM',
#  'RWTP',
#  'NSP',
#  'AXS',
#  'UPC',
#  'UNB',
#  'QGEN',
#  'NML',
#  'BTE',
#  'NRGV',
#  'BLNK',
#  'IGIC',
#  'RRGB',
#  'IFRX',
#  'P',
#  'GLSI',
#  'CHSCN',
#  'CWT',
#  'ICUCW',
#  'SSSSL',
#  'FSUN',
#  'EGY',
#  'BASE',
#  'MTEN',
#  'AIZN',
#  'GKOS',
#  'HPF',
#  'RNG',
#  'RFI',
#  'ILAG',
#  'TFIN',
#  'CXAIW',
#  'WTW',
#  'HAS',
#  'OESX',
#  'SGML',
#  'AMED',
#  'SPHR',
#  'ELA',
#  'XBPEW',
#  'GAB',
#  'RILYP',
#  'CLBT',
#  'RCI',
#  'SMRT',
#  'BBW',
#  'SOL',
#  'GTEC',
#  'NRDY',
#  'LIXTW',
#  'RDVT',
#  'SXC',
#  'SILO',
#  'KW',
#  'TYG',
#  'CHCI',
#  'SNRE',
#  'TBLA',
#  'FACT',
#  'NXLIW',
#  'SNOW',
#  'XOMAP',
#  'BIRK',
#  'JMIA',
#  'LEGT',
#  'RBLX',
#  'GHM',
#  'LYFT',
#  'HFWA',
#  'UKOMW',
#  'SUZ',
#  'SAP',
#  'TRSG',
#  'NAZ',
#  'VRNT',
#  'SFST',
#  'HSTM',
#  'FCF',
#  'NRXS',
#  'PARR',
#  'DX',
#  'TMHC',
#  'RAINW',
#  'KIND',
#  'ESRT',
#  'ODFL',
#  'AWH',
#  'ETY',
#  'IBEX',
#  'EHGO',
#  'MOFG',
#  'CLIR',
#  'CHPT',
#  'CVE',
#  'RXO',
#  'NTRSO',
#  'CGEN',
#  'CVLG',
#  'CCI',
#  'PCH',
#  'PRTC',
#  'BCX',
#  'PACB',
#  'AFMD',
#  'EFT',
#  'CGBD',
#  'QSIAW',
#  'FMTO',
#  'CNNE',
#  'SVII',
#  'GRFX',
#  'ORGN',
#  'SU',
#  'DOYU',
#  'NBIS',
#  'TSSI',
#  'LSAK',
#  'KROS',
#  'OACCW',
#  'UBCP',
#  'XRX',
#  'MOBBW',
#  'POR',
#  'MHF',
#  'ZKH',
#  'OXLCP',
#  'CCB',
#  'MTEX',
#  'BDN',
#  'ANNA',
#  'ELMD',
#  'HBM',
#  'SEPN',
#  'INSW',
#  'EPRT',
#  'FINS',
#  'SGRY',
#  'SYRE',
#  'JOE',
#  'DSGX',
#  'IPM',
#  'STSSW',
#  'DLR',
#  'RWT',
#  'OZ',
#  'MVBF',
#  'GNLN',
#  'NNY',
#  'ELF',
#  'MEG',
#  'CLMB',
#  'CNR',
#  'MC',
#  'MMI',
#  'MUJ',
#  'PLRZ',
#  'APLE',
#  'SPOK',
#  'VMD',
#  'EPRX',
#  'BKTI',
#  'SPH',
#  'DSU',
#  'GH',
#  'HLF',
#  'DQ',
#  'GASS',
#  'MARA',
#  'GP',
#  'SLMBP',
#  'SBT',
#  'NUVL',
#  'ZTO',
#  'NERV',
#  'SW',
#  'KTCC',
#  'DHIL',
#  'KRP',
#  'HLN',
#  'MWG',
#  'MULN',
#  'CLVT',
#  'SQFTP',
#  'BLZE',
#  'AWF',
#  'NAUT',
#  'EONR',
#  'ACIW',
#  'HWC',
#  'TDAC',
#  'BGH',
#  'MSI',
#  'BWMN',
#  'HYAC',
#  'AROW',
#  'EU',
#  'BBD',
#  'WHG',
#  'PRSO',
#  'LX',
#  'MHN',
#  'EIX',
#  'MBINL',
#  'SMP',
#  'PEO',
#  'FRO',
#  'GRNT',
#  'CXH',
#  'PAR',
#  'TMP',
#  'NOEMR',
#  'SNBR',
#  'GROW',
#  'BGSF',
#  'SN',
#  'SEE',
#  'NBY',
#  'NXTC',
#  'KMI',
#  'SBGI',
#  'FTHM',
#  'LYT',
#  'MXCT',
#  'LGCB',
#  'AREC',
#  'WB',
#  'OCEAW',
#  'NPK',
#  'VKI',
#  'ICU',
#  'SNTI',
#  'SMMT',
#  'WOOF',
#  'MVT',
#  'TENX',
#  'BEAGR',
#  'LTRX',
#  'CLEU',
#  'CPAC',
#  'CLSK',
#  'MSTR',
#  'CRIS',
#  'DYNXW',
#  'DDL',
#  'SRPT',
#  'GRNQ',
#  'RPM',
#  'HOPE',
#  'RZLT',
#  'FVRR',
#  'AVT',
#  'CLF',
#  'ESCA',
#  'FTAIN',
#  'JAMF',
#  'OUSTZ',
#  'CVI',
#  'APOS',
#  'NVO',
#  'KF',
#  'FBRT',
#  'LGL',
#  'MRSN',
#  'GBCI',
#  'BETR',
#  'NTR',
#  'F',
#  'SAT',
#  'GURE',
#  'SCNX',
#  'EEX',
#  'AQMS',
#  'LYB',
#  'LDI',
#  'PITA',
#  'ACU',
#  'BURU',
#  'SJ',
#  'EKSO',
#  'SSP',
#  'AHR',
#  'LFUS',
#  'CCSI',
#  'PTMN',
#  'ATEX',
#  'VRAX',
#  'BKE',
#  'DEI',
#  'DMF',
#  'RENB',
#  'BWAY',
#  'WELL',
#  'AAL',
#  'MKL',
#  'GYRO',
#  'FLC',
#  'AAP',
#  'SWTX',
#  'BCTX',
#  'TACT',
#  'NXGL',
#  'BRIA',
#  'LBTYB',
#  'WMS',
#  'FGB',
#  'ZKIN',
#  'SERA',
#  'SHMDW',
#  'RYI',
#  'HWH',
#  'MLI',
#  'ACM',
#  'CBRL',
#  'EOG',
#  'EDTK',
#  'BTMWW',
#  'BCDA',
#  'NEON',
#  'LQDT',
#  'INTG',
#  'OEC',
#  'UWMC',
#  'VREX',
#  'PLMK',
#  'FFIC',
#  'BIPC',
#  'YAAS',
#  'CWEN',
#  'COOTW',
#  'ALLR',
#  'DATSW',
#  'VTS',
#  'AMTX',
#  'ISTR',
#  'PAVM',
#  'LGI',
#  'ZG',
#  'KT',
#  'RXST',
#  'AGL',
#  'CADE',
#  'PDYNW',
#  'VACH',
#  'CURV',
#  'TFII',
#  'VNET',
#  'PAMT',
#  'NAAS',
#  'CODX',
#  'MSN',
#  'SCVL',
#  'MSGE',
#  'GNLX',
#  'INNV',
#  'REVBW',
#  'MYFW',
#  'SATS',
#  'CVRX',
#  'HOOD',
#  'SAM',
#  'COE',
#  'WTI',
#  'COUR',
#  'PSIX',
#  'SRZNW',
#  'CRMD',
#  'APOG',
#  'CIFR',
#  'BLNE',
#  'AVAV',
#  'KLTR',
#  'LUV',
#  'XRTX',
#  'DMRC',
#  'CATO',
#  'TLYS',
#  'ABEV',
#  'NXXT',
#  'WM',
#  'LOGC',
#  'MGR',
#  'FNV',
#  'CW',
#  'CNCK',
#  'JHX',
#  'FSBC',
#  'CMCO',
#  'LTBR',
#  'ALMS',
#  'IFBD',
#  'IVAC',
#  'AAT',
#  'BBWI',
#  'LOAN',
#  'ALTR',
#  'XPOF',
#  'ALTS',
#  'ANGHW',
#  'WWR',
#  'EFC',
#  'ILMN',
#  'HSDT',
#  'RMI',
#  'EDBLW',
#  'PAG',
#  'KLRS',
#  'WLYB',
#  'IAS',
#  'ALCYW',
#  'SHYF',
#  'PCK',
#  'UNIT',
#  'MRNO',
#  'NXPL',
#  'MCTR',
#  'LPX',
#  'VTN',
#  'NRSNW',
#  'USGO',
#  'MDRR',
#  'STX',
#  'DBL',
#  'MTRX',
#  'BTG',
#  'HFRO',
#  'FGMC',
#  'EBC',
#  'IDYA',
#  'OTIS',
#  'CMPX',
#  'SCL',
#  'HPH',
#  'TTWO',
#  'ARIS',
#  'NEUP',
#  'OVBC',
#  'BKU',
#  'PRTH',
#  'VINC',
#  'GOF',
#  'CCIX',
#  'WDFC',
#  'ELAN',
#  'GOGO',
#  'MDGL',
#  'MIR',
#  'PSMT',
#  'OLMA',
#  'FUL',
#  'XCUR',
#  'DIBS',
#  'GORV',
#  'GGZ',
#  'FBNC',
#  'TAOP',
#  'BPYPN',
#  'AEMD',
#  'NXT',
#  'CRVL',
#  'CLW',
#  'WRN',
#  'IMXI',
#  'BGS',
#  'BPOP',
#  'CXDO',
#  'LFST',
#  'NDLS',
#  'CIO',
#  'PW',
#  'WSO',
#  'SANG',
#  'ASTE',
#  'AVPT',
#  'YI',
#  'MNPR',
#  'EMP',
#  'W',
#  'FNWB',
#  'SNSE',
#  'NKTX',
#  'BHM',
#  'OXBR',
#  'DRRX',
#  'XPEL',
#  'PRH',
#  'ARMN',
#  'DEVS',
#  'MIN',
#  'WTFCP',
#  'GLQ',
#  'ASGI',
#  'RCKY',
#  'TOON',
#  'CHY',
#  'RBRK',
#  'CPB',
#  'IMTXW',
#  'ALC',
#  'AIXI',
#  'IMMX',
#  'BLDR',
#  'SDHY',
#  'AYRO',
#  'NPCE',
#  'SMPL',
#  'CAR',
#  'NBTX',
#  'HAE',
#  'HII',
#  'LAUR',
#  'FHB',
#  'SIRI',
#  'ACN',
#  'GCT',
#  'NKE',
#  'BVN',
#  'SEDG',
#  'TFINP',
#  'JZ',
#  'SENEB',
#  'SOAR',
#  'NLOP',
#  'FPI',
#  'ESI',
#  'INFY',
#  'BELFB',
#  'CAT',
#  'FLNC',
#  'QBTS',
#  'NGVC',
#  'OCFC',
#  'AHL',
#  'KORE',
#  'ANDE',
#  'GNTX',
#  'APLMW',
#  'VCSA',
#  'PDD',
#  'BJDX',
#  'UNCY',
#  'MFH',
#  'GOGL',
#  'GGROW',
#  'ARAY',
#  'FTHY',
#  'CTS',
#  'GBX',
#  'EURKU',
#  'RMSG',
#  'HCVI',
#  'TRNR',
#  'BATRA',
#  'CEPO',
#  'TISI',
#  'SPG',
#  'PETWW',
#  'VIAV',
#  'DKL',
#  'SST',
#  'CSWC',
#  'JBSS',
#  'MYD',
#  'KVAC',
#  'GOOS',
#  'PMTU',
#  'PKE',
#  'SLE',
#  'ASR',
#  'FLNG',
#  'UTHR',
#  'SPRO',
#  'CLNN',
#  ...}

# %% [markdown]
# Define inset()
#
# This will be used to check if the ticker in the df is in the set of valid tickers

# %%
def inset(key, set=tickers):
    return key in set

# %% [markdown]
# Evaluate Tickers and Drop Invalid Tickers

# %%
df["Include"] = df["Ticker"].apply(lambda key: inset(key))

df = df[df["Include"]==True].reset_index(drop=True)

df
# Out:
# C:\Users\rjrul\AppData\Local\Temp\ipykernel_11184\4221222880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Include"] = df["Ticker"].apply(lambda key: inset(key))
#                  Name       Party Chamber State Ticker        Date    Buy  \
# 0           Neal Dunn  Republican   House    FL   MSTR  2024-12-23   True
# 1      Dave McCormick  Republican  Senate   NaN    NaN   2024-2-17   True
# 2           Ro Khanna    Democrat   House    CA    LIN    2024-2-1  False
# 3           Ro Khanna    Democrat   House    CA   PENN   2024-2-14   True
# 4           Ro Khanna    Democrat   House    CA   PENN    2024-2-1   True
# ...               ...         ...     ...   ...    ...         ...    ...
# 18683       Ro Khanna    Democrat   House    CA   URBN    2024-2-4  False
# 18684       Ro Khanna    Democrat   House    CA     GM   2024-2-19  False
# 18685       Ro Khanna    Democrat   House    CA   ELAN   2024-2-21  False
# 18686       Ro Khanna    Democrat   House    CA    NaN    2024-2-1  False
# 18687       Ro Khanna    Democrat   House    CA     HD   2024-2-12   True
#
#         Sell Date_As_DateTime  Include
# 0      False       2024-12-23     True
# 1      False       2024-02-17     True
# 2       True       2024-02-01     True
# 3      False       2024-02-14     True
# 4      False       2024-02-01     True
# ...      ...              ...      ...
# 18683   True       2024-02-04     True
# 18684   True       2024-02-19     True
# 18685   True       2024-02-21     True
# 18686   True       2024-02-01     True
# 18687  False       2024-02-12     True
#
# [18688 rows x 10 columns]

# %% [markdown]
# ### Save Cleaned Data to CSV

# %%
df.to_csv(data_path+"02 Trade Scraping\\"+"transition_log_scraped.csv")

# %% [markdown]
# ## Split Data by Transaction Type

# %%
buydf = df[df["Buy"]==True][['Name',"Party",'Chamber', 'State', 'Ticker', 'Date']].reset_index(drop=True)

buydf
# Out:
#                 Name       Party Chamber State Ticker        Date
# 0          Neal Dunn  Republican   House    FL   MSTR  2024-12-23
# 1     Dave McCormick  Republican  Senate   NaN    NaN   2024-2-17
# 2          Ro Khanna    Democrat   House    CA   PENN   2024-2-14
# 3          Ro Khanna    Democrat   House    CA   PENN    2024-2-1
# 4          Ro Khanna    Democrat   House    CA    SYY   2024-1-31
# ...              ...         ...     ...   ...    ...         ...
# 9493       Ro Khanna    Democrat   House    CA    SYY   2024-2-22
# 9494       Ro Khanna    Democrat   House    CA   PENN   2024-2-14
# 9495       Ro Khanna    Democrat   House    CA   PENN    2024-2-1
# 9496       Ro Khanna    Democrat   House    CA    SYY   2024-1-31
# 9497       Ro Khanna    Democrat   House    CA     HD   2024-2-12
#
# [9498 rows x 6 columns]

# %%
selldf = df[df["Sell"]==True][['Name',"Party",'Chamber', 'State', 'Ticker', 'Date']].reset_index(drop=True)

selldf
# Out:
#            Name     Party Chamber State Ticker       Date
# 0     Ro Khanna  Democrat   House    CA    LIN   2024-2-1
# 1     Ro Khanna  Democrat   House    CA    IFF  2024-2-20
# 2     Ro Khanna  Democrat   House    CA    CRI  2024-2-22
# 3     Ro Khanna  Democrat   House    CA   URBN   2024-2-4
# 4     Ro Khanna  Democrat   House    CA     GM  2024-2-19
# ...         ...       ...     ...   ...    ...        ...
# 9134  Ro Khanna  Democrat   House    CA    CRI  2024-2-22
# 9135  Ro Khanna  Democrat   House    CA   URBN   2024-2-4
# 9136  Ro Khanna  Democrat   House    CA     GM  2024-2-19
# 9137  Ro Khanna  Democrat   House    CA   ELAN  2024-2-21
# 9138  Ro Khanna  Democrat   House    CA    NaN   2024-2-1
#
# [9139 rows x 6 columns]

# %% [markdown]
# ## Integrate Data by Matching Transactions

# %%
merged_df = buydf.merge(selldf, on=["Name", "Ticker", "Party", "Chamber", "State"], suffixes=("_buy", "_sell"))

merged_df
# Out:
#              Name     Party Chamber State Ticker   Date_buy  Date_sell
# 0       Ro Khanna  Democrat   House    CA   PENN  2024-2-14  2024-6-20
# 1       Ro Khanna  Democrat   House    CA   PENN  2024-2-14  2024-6-20
# 2       Ro Khanna  Democrat   House    CA   PENN  2024-2-14  2024-6-19
# 3       Ro Khanna  Democrat   House    CA   PENN  2024-2-14  2024-6-11
# 4       Ro Khanna  Democrat   House    CA   PENN  2024-2-14  2024-6-19
# ...           ...       ...     ...   ...    ...        ...        ...
# 434608  Ro Khanna  Democrat   House    CA     HD  2024-2-12  2023-5-22
# 434609  Ro Khanna  Democrat   House    CA     HD  2024-2-12   2024-7-9
# 434610  Ro Khanna  Democrat   House    CA     HD  2024-2-12   2024-7-9
# 434611  Ro Khanna  Democrat   House    CA     HD  2024-2-12  2024-4-25
# 434612  Ro Khanna  Democrat   House    CA     HD  2024-2-12  2024-4-22
#
# [434613 rows x 7 columns]

# %%
matched_df = merged_df.groupby(["Name", "Ticker", "Party", "Chamber", "State"]).agg(
    Earliest_Buy_Date=("Date_buy", "min"),
    Latest_Sell_Date=("Date_sell", "max")
).reset_index()

matched_df = matched_df.rename(columns={"Earliest_Buy_Date" : "Buy Date", "Latest_Sell_Date" : "Sell Date"})

matched_df["Buy Date"] = pd.to_datetime(matched_df["Buy Date"], errors="coerce")
matched_df["Sell Date"] = pd.to_datetime(matched_df["Sell Date"], errors="coerce")

#Filter out when Earliest Buy Date is After Latest Sell Date , since stocks could have been bought before sample range
matched_df = matched_df[matched_df["Sell Date"] >= matched_df["Buy Date"]]

matched_df["Buy Date"] = matched_df["Buy Date"].dt.strftime("%Y-%#m-%#d")
matched_df["Sell Date"] = matched_df["Sell Date"].dt.strftime("%Y-%#m-%#d")

matched_df
# Out:
#                Name Ticker       Party Chamber State   Buy Date  Sell Date
# 0      Bill Keating   ABNB    Democrat   House    MA  2023-1-17  2024-5-16
# 1      Bill Keating     BA    Democrat   House    MA  2023-9-14   2024-2-7
# 2      Bill Keating    BAC    Democrat   House    MA  2024-1-17  2024-9-10
# 4      Bill Keating     GM    Democrat   House    MA  2023-6-26  2024-9-10
# 5      Bill Keating  GOOGL    Democrat   House    MA  2023-2-12  2024-5-16
# ...             ...    ...         ...     ...   ...        ...        ...
# 1473  Virginia Foxx   FLNG  Republican   House    NC   2023-1-3  2024-12-5
# 1474  Virginia Foxx     MO  Republican   House    NC  2023-1-16   2024-1-9
# 1475  Virginia Foxx    PAA  Republican   House    NC  2023-3-23  2023-10-2
# 1476  Virginia Foxx      T  Republican   House    NC  2023-1-31  2024-12-5
# 1477  Virginia Foxx    TAK  Republican   House    NC  2023-2-15  2023-8-28
#
# [1356 rows x 7 columns]

# %% [markdown]
# ## Output Matched and Integrated Data

# %%
matched_df.to_csv(data_path+"03 Data Integration\\"+"transactions_matched.csv", index=False)
