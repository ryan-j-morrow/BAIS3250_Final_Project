# %% [markdown]
# # Scraping Capitol Trades

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd  # For handling data in DataFrame
from selenium import webdriver  # For controlling the web browser and interacting with HTML content
from selenium.webdriver.chrome.service import Service  # For setting up ChromeDriver as a service
from selenium.webdriver.common.by import By  # To locate HTML elements by XPath
from selenium.webdriver.chrome.options import Options  # For handling Chrome options
from webdriver_manager.chrome import ChromeDriverManager  # For automatic ChromeDriver installation
import time  # For handling wait times
import random  # For randomizing scroll and wait times
import os
from datetime import datetime

# %% [markdown]
# ### Set Up Paths

# %%
home_path = os.getcwd()
home_path = os.path.dirname(home_path)
home_path += "\\"

data_path = home_path + "02 Data Files\\"

print(data_path)
# Out:
# c:\Users\rjrul\OneDrive - University of Iowa\00 Current Semester\01 BAIS 3250 - Data Wrangling\05 Final Project\02 Data Files\

# %% [markdown]
# ## Set Up Scraping Browser

# %%
def get_browser():# Set up ChromeDriver using webdriver_manager
    chrome_options = Options()  # Initialize Chrome options (optional)

    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--disable-images")
    chrome_options.add_argument("--disable-extensions")
    chrome_options.add_argument("--disable-javascript")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--no-sandbox")

    service = Service(ChromeDriverManager().install())  # Install and set up ChromeDriver as a service

    # Create a ChromeDriver instance
    browser = webdriver.Chrome(service=service, options=chrome_options)

    return browser

# %%
# Function to scroll down the page randomly
def random_scroll(browser, total_wait_time=3):
    # Get the total height of the page
    total_height = browser.execute_script("return document.body.scrollHeight")
    
    # Number of steps to scroll (adjust this number for finer control)
    scroll_steps = random.randint(3, 7)
    
    # Height to scroll per step
    scroll_increment = total_height // scroll_steps
    
    # Time to wait per step
    time_per_step = total_wait_time / scroll_steps
    
    # Scroll in steps
    for step in range(scroll_steps):
        # Scroll down
        browser.execute_script(f"window.scrollBy(0, {scroll_increment});")
        # Wait for a random time between each scroll
        time.sleep(random.uniform(0.5 * time_per_step, 1.5 * time_per_step))
    
    # Ensure we scroll to the bottom of the page
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %% [markdown]
# ## Scrape Data

# %%
def scrape(start, end, subset=1):
    url = 'https://www.capitoltrades.com/trades?page='

    #Initialize Next Flag and Page Counter
    next_flag = True
    page_counter = start #Start Page
    first_page = page_counter
    max_pages = end-start 

    max_pages += page_counter

    browser = get_browser()

    browser.get(url+str(page_counter))
    browser.minimize_window()
    # Wait a random time between 1-5 seconds before starting
    time.sleep(random.uniform(1, 5))

    month_dict = {
    "Jan": 1, "Feb": 2, "Mar": 3, "Apr": 4, "May": 5, "Jun": 6,
    "Jul": 7, "Aug": 8, "Sept": 9, "Oct": 10, "Nov": 11, "Dec": 12
    }



    #Master Dictionary to Track all Records
    master_dict = {}

    #Initialize Timing
    end_time = datetime.now()
    start_time = datetime.now()

    while next_flag == True and page_counter <= max_pages:
        #Look for Page Limit
        scrapetime = (end_time - start_time).total_seconds()
        start_time = datetime.now()
        

        if page_counter == first_page:
            p = browser.find_element(By.CSS_SELECTOR, ".hidden.leading-7.sm\\:block")
            bs = p.find_elements(By.TAG_NAME, "b")
            page_limit = bs[1].text
            page_limit = int(page_limit)
            page_limit = min(max_pages, page_limit)
            scrapetime = 0

        

        print(f"\nScraping Subset #{subset}, Page {page_counter-first_page+1} out of {page_limit-first_page+1} total pages ({round(scrapetime,1)}s)...") #Communicate to Terminal

        #Scrape

        try:
            table = browser.find_element(By.CSS_SELECTOR, ".w-full.caption-bottom.text-size-3.text-txt")

            body = table.find_element(By.TAG_NAME, "tbody")

            records = body.find_elements(By.TAG_NAME, "tr")

            for i, record in enumerate(records):
                record_dict = {}
                id = str(page_counter)+"-"+str(i)

                tds = record.find_elements(By.TAG_NAME, "td")
                
                
                #Scrape Name
                div1 = tds[0].find_element(By.TAG_NAME, "div")
                div2 = div1.find_element(By.TAG_NAME, "div")
                div3 = div2.find_element(By.TAG_NAME, "div")
                h2 = div3.find_element(By.TAG_NAME, "h2")
                a = h2.find_element(By.TAG_NAME, "a")
                name = a.text

                #Scrape Party, Chamber, State
                div4 = div3.find_element(By.TAG_NAME, "div")
                spans = div4.find_elements(By.TAG_NAME, "span")
                party = spans[0].text
                chamber = spans[1].text
                state = spans[2].text

                #Scrape Traded Ticker
                div1 = tds[1].find_element(By.TAG_NAME, "div")
                div2 = div1.find_element(By.TAG_NAME, "div")
                div3 = div2.find_element(By.TAG_NAME, "div")
                div4 = div3.find_element(By.TAG_NAME, "div")
                span = div4.find_element(By.TAG_NAME, "span")
                ticker = span.text.split(":")[0]

                #Scrape Trade Date
                div1 = tds[3].find_element(By.TAG_NAME, "div")
                div2 = div1.find_element(By.TAG_NAME, "div")
                divs = div2.find_elements(By.TAG_NAME, "div")
                day = divs[0].text.split(" ")[0]
                month = divs[0].text.split(" ")[1]
                month = month_dict[month]

                year = divs[1].text
                date = str(year)+"-"+str(month)+"-"+str(day)

                #Scrape Trade Type
                div1 = tds[6].find_element(By.TAG_NAME, "div")
                span = div1.find_element(By.TAG_NAME, "span")
                buy = span.text.lower() == 'buy'
                sell = span.text.lower() == 'sell'
                
                
                
                #Store Record Data in Record Dictionary
                record_dict["Name"] = name
                record_dict["Party"] = party
                record_dict["Chamber"] = chamber
                record_dict["State"] = state
                record_dict["Ticker"] = ticker
                record_dict["Date"] = date
                record_dict["Buy"] = buy
                record_dict["Sell"] = sell


                #Add Record to Master Dictionary
                master_dict[id] = record_dict
                
        except Exception as e:
            print("Error... Moving On")
            print(e)
            
        next_flag = page_counter<page_limit

        if next_flag == True:
            #Go to Next Page
            page_counter += 1 #Track Page
            browser.get(url+str(page_counter))
            random_scroll(browser)
        else:
            #Communicate to Terminal and End
            print("\nNo Next Page")

        time.sleep(random.uniform(.25, 1.5))
        end_time = datetime.now()

    #Close automated browser
    browser.close()

    df = pd.DataFrame.from_dict(master_dict, orient='Index')
    df = df.reset_index(drop=True)

    #df["Date_As_DateTime"] = pd.to_datetime(df["Date"])

    df.to_csv(data_path+"02 Trade Scraping\\"+f"transaction_log_scraped_subset{subset}.csv", index=False)

    df = 0

# %%
start = 1
end = 3000
step = 100

count = 15

curr_end = 1500


while curr_end < end:
    count += 1
    curr_start = curr_end+1
    scrape(curr_start, min(curr_start+step,end),count)
   
    curr_end += step
# Out:
# Scraping Subset #16, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #16, Page 2 out of 101 total pages (7.5s)...
#
# Scraping Subset #16, Page 3 out of 101 total pages (7.7s)...
#
# Scraping Subset #16, Page 4 out of 101 total pages (21.8s)...
#
# Scraping Subset #16, Page 5 out of 101 total pages (7.4s)...
#
# Scraping Subset #16, Page 6 out of 101 total pages (7.8s)...
#
# Scraping Subset #16, Page 7 out of 101 total pages (8.7s)...
#
# Scraping Subset #16, Page 8 out of 101 total pages (10.6s)...
#
# Scraping Subset #16, Page 9 out of 101 total pages (8.5s)...
#
# Scraping Subset #16, Page 10 out of 101 total pages (8.5s)...
#
# Scraping Subset #16, Page 11 out of 101 total pages (9.3s)...
#
# Scraping Subset #16, Page 12 out of 101 total pages (25.0s)...
#
# Scraping Subset #16, Page 13 out of 101 total pages (9.4s)...
#
# Scraping Subset #16, Page 14 out of 101 total pages (26.0s)...
#
# Scraping Subset #16, Page 15 out of 101 total pages (8.4s)...
#
# Scraping Subset #16, Page 16 out of 101 total pages (8.0s)...
#
# Scraping Subset #16, Page 17 out of 101 total pages (14.2s)...
#
# Scraping Subset #16, Page 18 out of 101 total pages (9.3s)...
#
# Scraping Subset #16, Page 19 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 20 out of 101 total pages (7.8s)...
#
# Scraping Subset #16, Page 21 out of 101 total pages (8.7s)...
#
# Scraping Subset #16, Page 22 out of 101 total pages (8.9s)...
#
# Scraping Subset #16, Page 23 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 24 out of 101 total pages (10.2s)...
#
# Scraping Subset #16, Page 25 out of 101 total pages (10.0s)...
#
# Scraping Subset #16, Page 26 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 27 out of 101 total pages (10.1s)...
#
# Scraping Subset #16, Page 28 out of 101 total pages (10.7s)...
#
# Scraping Subset #16, Page 29 out of 101 total pages (10.2s)...
#
# Scraping Subset #16, Page 30 out of 101 total pages (9.1s)...
#
# Scraping Subset #16, Page 31 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 32 out of 101 total pages (9.1s)...
#
# Scraping Subset #16, Page 33 out of 101 total pages (8.7s)...
#
# Scraping Subset #16, Page 34 out of 101 total pages (8.9s)...
#
# Scraping Subset #16, Page 35 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 36 out of 101 total pages (9.1s)...
#
# Scraping Subset #16, Page 37 out of 101 total pages (8.1s)...
#
# Scraping Subset #16, Page 38 out of 101 total pages (8.8s)...
#
# Scraping Subset #16, Page 39 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 40 out of 101 total pages (10.1s)...
#
# Scraping Subset #16, Page 41 out of 101 total pages (9.0s)...
#
# Scraping Subset #16, Page 42 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 43 out of 101 total pages (8.6s)...
#
# Scraping Subset #16, Page 44 out of 101 total pages (8.5s)...
#
# Scraping Subset #16, Page 45 out of 101 total pages (9.3s)...
#
# Scraping Subset #16, Page 46 out of 101 total pages (9.9s)...
#
# Scraping Subset #16, Page 47 out of 101 total pages (8.9s)...
#
# Scraping Subset #16, Page 48 out of 101 total pages (8.4s)...
#
# Scraping Subset #16, Page 49 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 50 out of 101 total pages (10.4s)...
#
# Scraping Subset #16, Page 51 out of 101 total pages (10.3s)...
#
# Scraping Subset #16, Page 52 out of 101 total pages (9.4s)...
#
# Scraping Subset #16, Page 53 out of 101 total pages (9.9s)...
#
# Scraping Subset #16, Page 54 out of 101 total pages (9.7s)...
#
# Scraping Subset #16, Page 55 out of 101 total pages (10.5s)...
#
# Scraping Subset #16, Page 56 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 57 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 58 out of 101 total pages (9.4s)...
#
# Scraping Subset #16, Page 59 out of 101 total pages (9.3s)...
#
# Scraping Subset #16, Page 60 out of 101 total pages (9.4s)...
#
# Scraping Subset #16, Page 61 out of 101 total pages (9.7s)...
#
# Scraping Subset #16, Page 62 out of 101 total pages (10.1s)...
#
# Scraping Subset #16, Page 63 out of 101 total pages (9.9s)...
#
# Scraping Subset #16, Page 64 out of 101 total pages (10.5s)...
#
# Scraping Subset #16, Page 65 out of 101 total pages (8.5s)...
#
# Scraping Subset #16, Page 66 out of 101 total pages (10.4s)...
#
# Scraping Subset #16, Page 67 out of 101 total pages (10.0s)...
#
# Scraping Subset #16, Page 68 out of 101 total pages (9.6s)...
#
# Scraping Subset #16, Page 69 out of 101 total pages (10.1s)...
#
# Scraping Subset #16, Page 70 out of 101 total pages (9.4s)...
#
# Scraping Subset #16, Page 71 out of 101 total pages (8.8s)...
#
# Scraping Subset #16, Page 72 out of 101 total pages (8.3s)...
#
# Scraping Subset #16, Page 73 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 74 out of 101 total pages (7.8s)...
#
# Scraping Subset #16, Page 75 out of 101 total pages (7.8s)...
#
# Scraping Subset #16, Page 76 out of 101 total pages (8.5s)...
#
# Scraping Subset #16, Page 77 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 78 out of 101 total pages (8.4s)...
#
# Scraping Subset #16, Page 79 out of 101 total pages (8.5s)...
#
# Scraping Subset #16, Page 80 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 81 out of 101 total pages (10.7s)...
#
# Scraping Subset #16, Page 82 out of 101 total pages (9.8s)...
#
# Scraping Subset #16, Page 83 out of 101 total pages (9.9s)...
#
# Scraping Subset #16, Page 84 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 85 out of 101 total pages (8.0s)...
#
# Scraping Subset #16, Page 86 out of 101 total pages (9.2s)...
#
# Scraping Subset #16, Page 87 out of 101 total pages (8.7s)...
#
# Scraping Subset #16, Page 88 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 89 out of 101 total pages (13.5s)...
#
# Scraping Subset #16, Page 90 out of 101 total pages (9.3s)...
#
# Scraping Subset #16, Page 91 out of 101 total pages (9.8s)...
#
# Scraping Subset #16, Page 92 out of 101 total pages (8.9s)...
#
# Scraping Subset #16, Page 93 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 94 out of 101 total pages (11.1s)...
#
# Scraping Subset #16, Page 95 out of 101 total pages (8.9s)...
#
# Scraping Subset #16, Page 96 out of 101 total pages (9.9s)...
#
# Scraping Subset #16, Page 97 out of 101 total pages (9.5s)...
#
# Scraping Subset #16, Page 98 out of 101 total pages (9.0s)...
#
# Scraping Subset #16, Page 99 out of 101 total pages (10.3s)...
#
# Scraping Subset #16, Page 100 out of 101 total pages (9.4s)...
#
# Scraping Subset #16, Page 101 out of 101 total pages (8.6s)...
#
# No Next Page
#
# Scraping Subset #17, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #17, Page 2 out of 101 total pages (8.3s)...
#
# Scraping Subset #17, Page 3 out of 101 total pages (7.6s)...
#
# Scraping Subset #17, Page 4 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 5 out of 101 total pages (8.2s)...
#
# Scraping Subset #17, Page 6 out of 101 total pages (8.1s)...
#
# Scraping Subset #17, Page 7 out of 101 total pages (8.6s)...
#
# Scraping Subset #17, Page 8 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 9 out of 101 total pages (7.0s)...
#
# Scraping Subset #17, Page 10 out of 101 total pages (9.7s)...
#
# Scraping Subset #17, Page 11 out of 101 total pages (8.4s)...
#
# Scraping Subset #17, Page 12 out of 101 total pages (9.3s)...
#
# Scraping Subset #17, Page 13 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 14 out of 101 total pages (8.7s)...
#
# Scraping Subset #17, Page 15 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 16 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 17 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 18 out of 101 total pages (9.6s)...
#
# Scraping Subset #17, Page 19 out of 101 total pages (9.7s)...
#
# Scraping Subset #17, Page 20 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 21 out of 101 total pages (9.1s)...
#
# Scraping Subset #17, Page 22 out of 101 total pages (9.4s)...
#
# Scraping Subset #17, Page 23 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 24 out of 101 total pages (9.4s)...
#
# Scraping Subset #17, Page 25 out of 101 total pages (9.3s)...
#
# Scraping Subset #17, Page 26 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 27 out of 101 total pages (9.3s)...
#
# Scraping Subset #17, Page 28 out of 101 total pages (9.4s)...
#
# Scraping Subset #17, Page 29 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 30 out of 101 total pages (8.9s)...
#
# Scraping Subset #17, Page 31 out of 101 total pages (9.4s)...
#
# Scraping Subset #17, Page 32 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 33 out of 101 total pages (8.2s)...
#
# Scraping Subset #17, Page 34 out of 101 total pages (8.6s)...
#
# Scraping Subset #17, Page 35 out of 101 total pages (8.6s)...
#
# Scraping Subset #17, Page 36 out of 101 total pages (9.6s)...
#
# Scraping Subset #17, Page 37 out of 101 total pages (8.7s)...
#
# Scraping Subset #17, Page 38 out of 101 total pages (10.1s)...
#
# Scraping Subset #17, Page 39 out of 101 total pages (10.0s)...
#
# Scraping Subset #17, Page 40 out of 101 total pages (9.1s)...
#
# Scraping Subset #17, Page 41 out of 101 total pages (9.6s)...
#
# Scraping Subset #17, Page 42 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 43 out of 101 total pages (10.4s)...
#
# Scraping Subset #17, Page 44 out of 101 total pages (7.6s)...
#
# Scraping Subset #17, Page 45 out of 101 total pages (8.7s)...
#
# Scraping Subset #17, Page 46 out of 101 total pages (11.2s)...
#
# Scraping Subset #17, Page 47 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 48 out of 101 total pages (9.3s)...
#
# Scraping Subset #17, Page 49 out of 101 total pages (10.3s)...
#
# Scraping Subset #17, Page 50 out of 101 total pages (10.1s)...
#
# Scraping Subset #17, Page 51 out of 101 total pages (9.4s)...
#
# Scraping Subset #17, Page 52 out of 101 total pages (11.0s)...
#
# Scraping Subset #17, Page 53 out of 101 total pages (10.4s)...
#
# Scraping Subset #17, Page 54 out of 101 total pages (9.9s)...
#
# Scraping Subset #17, Page 55 out of 101 total pages (10.0s)...
#
# Scraping Subset #17, Page 56 out of 101 total pages (9.6s)...
#
# Scraping Subset #17, Page 57 out of 101 total pages (10.5s)...
#
# Scraping Subset #17, Page 58 out of 101 total pages (10.4s)...
#
# Scraping Subset #17, Page 59 out of 101 total pages (8.3s)...
#
# Scraping Subset #17, Page 60 out of 101 total pages (10.1s)...
#
# Scraping Subset #17, Page 61 out of 101 total pages (9.2s)...
#
# Scraping Subset #17, Page 62 out of 101 total pages (9.1s)...
#
# Scraping Subset #17, Page 63 out of 101 total pages (9.8s)...
#
# Scraping Subset #17, Page 64 out of 101 total pages (9.7s)...
#
# Scraping Subset #17, Page 65 out of 101 total pages (8.6s)...
#
# Scraping Subset #17, Page 66 out of 101 total pages (7.7s)...
#
# Scraping Subset #17, Page 67 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 68 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 69 out of 101 total pages (8.8s)...
#
# Scraping Subset #17, Page 70 out of 101 total pages (9.9s)...
#
# Scraping Subset #17, Page 71 out of 101 total pages (9.9s)...
#
# Scraping Subset #17, Page 72 out of 101 total pages (10.2s)...
#
# Scraping Subset #17, Page 73 out of 101 total pages (9.2s)...
#
# Scraping Subset #17, Page 74 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 75 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 76 out of 101 total pages (8.3s)...
#
# Scraping Subset #17, Page 77 out of 101 total pages (10.1s)...
#
# Scraping Subset #17, Page 78 out of 101 total pages (10.4s)...
#
# Scraping Subset #17, Page 79 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 80 out of 101 total pages (8.2s)...
#
# Scraping Subset #17, Page 81 out of 101 total pages (9.9s)...
#
# Scraping Subset #17, Page 82 out of 101 total pages (10.8s)...
#
# Scraping Subset #17, Page 83 out of 101 total pages (10.3s)...
#
# Scraping Subset #17, Page 84 out of 101 total pages (8.6s)...
#
# Scraping Subset #17, Page 85 out of 101 total pages (7.5s)...
#
# Scraping Subset #17, Page 86 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 87 out of 101 total pages (9.0s)...
#
# Scraping Subset #17, Page 88 out of 101 total pages (10.0s)...
#
# Scraping Subset #17, Page 89 out of 101 total pages (10.6s)...
#
# Scraping Subset #17, Page 90 out of 101 total pages (8.9s)...
#
# Scraping Subset #17, Page 91 out of 101 total pages (9.9s)...
#
# Scraping Subset #17, Page 92 out of 101 total pages (10.5s)...
#
# Scraping Subset #17, Page 93 out of 101 total pages (8.5s)...
#
# Scraping Subset #17, Page 94 out of 101 total pages (9.6s)...
#
# Scraping Subset #17, Page 95 out of 101 total pages (9.2s)...
#
# Scraping Subset #17, Page 96 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 97 out of 101 total pages (11.3s)...
#
# Scraping Subset #17, Page 98 out of 101 total pages (11.0s)...
#
# Scraping Subset #17, Page 99 out of 101 total pages (9.9s)...
#
# Scraping Subset #17, Page 100 out of 101 total pages (9.5s)...
#
# Scraping Subset #17, Page 101 out of 101 total pages (9.2s)...
#
# No Next Page
#
# Scraping Subset #18, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #18, Page 2 out of 101 total pages (7.9s)...
#
# Scraping Subset #18, Page 3 out of 101 total pages (9.2s)...
#
# Scraping Subset #18, Page 4 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 5 out of 101 total pages (8.5s)...
#
# Scraping Subset #18, Page 6 out of 101 total pages (8.5s)...
#
# Scraping Subset #18, Page 7 out of 101 total pages (7.8s)...
#
# Scraping Subset #18, Page 8 out of 101 total pages (8.0s)...
#
# Scraping Subset #18, Page 9 out of 101 total pages (8.1s)...
#
# Scraping Subset #18, Page 10 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 11 out of 101 total pages (9.5s)...
#
# Scraping Subset #18, Page 12 out of 101 total pages (8.5s)...
#
# Scraping Subset #18, Page 13 out of 101 total pages (8.9s)...
#
# Scraping Subset #18, Page 14 out of 101 total pages (8.8s)...
#
# Scraping Subset #18, Page 15 out of 101 total pages (8.8s)...
#
# Scraping Subset #18, Page 16 out of 101 total pages (8.8s)...
#
# Scraping Subset #18, Page 17 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 18 out of 101 total pages (8.4s)...
#
# Scraping Subset #18, Page 19 out of 101 total pages (9.8s)...
#
# Scraping Subset #18, Page 20 out of 101 total pages (8.8s)...
#
# Scraping Subset #18, Page 21 out of 101 total pages (9.2s)...
#
# Scraping Subset #18, Page 22 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 23 out of 101 total pages (9.1s)...
#
# Scraping Subset #18, Page 24 out of 101 total pages (8.7s)...
#
# Scraping Subset #18, Page 25 out of 101 total pages (9.2s)...
#
# Scraping Subset #18, Page 26 out of 101 total pages (9.5s)...
#
# Scraping Subset #18, Page 27 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 28 out of 101 total pages (9.9s)...
#
# Scraping Subset #18, Page 29 out of 101 total pages (8.3s)...
#
# Scraping Subset #18, Page 30 out of 101 total pages (9.7s)...
#
# Scraping Subset #18, Page 31 out of 101 total pages (8.9s)...
#
# Scraping Subset #18, Page 32 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 33 out of 101 total pages (50.3s)...
#
# Scraping Subset #18, Page 34 out of 101 total pages (8.1s)...
#
# Scraping Subset #18, Page 35 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 36 out of 101 total pages (8.7s)...
#
# Scraping Subset #18, Page 37 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 38 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 39 out of 101 total pages (8.5s)...
#
# Scraping Subset #18, Page 40 out of 101 total pages (9.2s)...
#
# Scraping Subset #18, Page 41 out of 101 total pages (8.6s)...
#
# Scraping Subset #18, Page 42 out of 101 total pages (10.3s)...
#
# Scraping Subset #18, Page 43 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 44 out of 101 total pages (9.7s)...
#
# Scraping Subset #18, Page 45 out of 101 total pages (8.9s)...
#
# Scraping Subset #18, Page 46 out of 101 total pages (9.6s)...
#
# Scraping Subset #18, Page 47 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 48 out of 101 total pages (10.1s)...
#
# Scraping Subset #18, Page 49 out of 101 total pages (10.0s)...
#
# Scraping Subset #18, Page 50 out of 101 total pages (9.7s)...
#
# Scraping Subset #18, Page 51 out of 101 total pages (10.3s)...
#
# Scraping Subset #18, Page 52 out of 101 total pages (8.3s)...
#
# Scraping Subset #18, Page 53 out of 101 total pages (9.1s)...
#
# Scraping Subset #18, Page 54 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 55 out of 101 total pages (10.6s)...
#
# Scraping Subset #18, Page 56 out of 101 total pages (10.1s)...
#
# Scraping Subset #18, Page 57 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 58 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 59 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 60 out of 101 total pages (8.6s)...
#
# Scraping Subset #18, Page 61 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 62 out of 101 total pages (10.1s)...
#
# Scraping Subset #18, Page 63 out of 101 total pages (10.0s)...
#
# Scraping Subset #18, Page 64 out of 101 total pages (9.2s)...
#
# Scraping Subset #18, Page 65 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 66 out of 101 total pages (9.5s)...
#
# Scraping Subset #18, Page 67 out of 101 total pages (7.8s)...
#
# Scraping Subset #18, Page 68 out of 101 total pages (8.4s)...
#
# Scraping Subset #18, Page 69 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 70 out of 101 total pages (10.7s)...
#
# Scraping Subset #18, Page 71 out of 101 total pages (8.3s)...
#
# Scraping Subset #18, Page 72 out of 101 total pages (8.8s)...
#
# Scraping Subset #18, Page 73 out of 101 total pages (10.2s)...
#
# Scraping Subset #18, Page 74 out of 101 total pages (10.4s)...
#
# Scraping Subset #18, Page 75 out of 101 total pages (8.1s)...
#
# Scraping Subset #18, Page 76 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 77 out of 101 total pages (8.5s)...
#
# Scraping Subset #18, Page 78 out of 101 total pages (8.6s)...
#
# Scraping Subset #18, Page 79 out of 101 total pages (8.0s)...
#
# Scraping Subset #18, Page 80 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 81 out of 101 total pages (10.3s)...
#
# Scraping Subset #18, Page 82 out of 101 total pages (8.8s)...
#
# Scraping Subset #18, Page 83 out of 101 total pages (8.2s)...
#
# Scraping Subset #18, Page 84 out of 101 total pages (9.5s)...
#
# Scraping Subset #18, Page 85 out of 101 total pages (9.0s)...
#
# Scraping Subset #18, Page 86 out of 101 total pages (9.3s)...
#
# Scraping Subset #18, Page 87 out of 101 total pages (11.6s)...
#
# Scraping Subset #18, Page 88 out of 101 total pages (10.5s)...
#
# Scraping Subset #18, Page 89 out of 101 total pages (9.7s)...
#
# Scraping Subset #18, Page 90 out of 101 total pages (9.8s)...
#
# Scraping Subset #18, Page 91 out of 101 total pages (10.4s)...
#
# Scraping Subset #18, Page 92 out of 101 total pages (9.9s)...
#
# Scraping Subset #18, Page 93 out of 101 total pages (9.8s)...
#
# Scraping Subset #18, Page 94 out of 101 total pages (9.8s)...
#
# Scraping Subset #18, Page 95 out of 101 total pages (8.9s)...
#
# Scraping Subset #18, Page 96 out of 101 total pages (9.6s)...
#
# Scraping Subset #18, Page 97 out of 101 total pages (9.9s)...
#
# Scraping Subset #18, Page 98 out of 101 total pages (10.0s)...
#
# Scraping Subset #18, Page 99 out of 101 total pages (9.5s)...
#
# Scraping Subset #18, Page 100 out of 101 total pages (9.4s)...
#
# Scraping Subset #18, Page 101 out of 101 total pages (10.5s)...
#
# No Next Page
#
# Scraping Subset #19, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #19, Page 2 out of 101 total pages (8.5s)...
#
# Scraping Subset #19, Page 3 out of 101 total pages (8.2s)...
#
# Scraping Subset #19, Page 4 out of 101 total pages (43.4s)...
#
# Scraping Subset #19, Page 5 out of 101 total pages (8.4s)...
#
# Scraping Subset #19, Page 6 out of 101 total pages (10.2s)...
#
# Scraping Subset #19, Page 7 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 8 out of 101 total pages (8.1s)...
#
# Scraping Subset #19, Page 9 out of 101 total pages (7.8s)...
#
# Scraping Subset #19, Page 10 out of 101 total pages (8.8s)...
#
# Scraping Subset #19, Page 11 out of 101 total pages (9.8s)...
#
# Scraping Subset #19, Page 12 out of 101 total pages (9.3s)...
#
# Scraping Subset #19, Page 13 out of 101 total pages (28.3s)...
#
# Scraping Subset #19, Page 14 out of 101 total pages (9.2s)...
#
# Scraping Subset #19, Page 15 out of 101 total pages (10.2s)...
#
# Scraping Subset #19, Page 16 out of 101 total pages (8.7s)...
#
# Scraping Subset #19, Page 17 out of 101 total pages (9.3s)...
#
# Scraping Subset #19, Page 18 out of 101 total pages (8.4s)...
#
# Scraping Subset #19, Page 19 out of 101 total pages (8.9s)...
#
# Scraping Subset #19, Page 20 out of 101 total pages (8.7s)...
#
# Scraping Subset #19, Page 21 out of 101 total pages (8.6s)...
#
# Scraping Subset #19, Page 22 out of 101 total pages (9.8s)...
#
# Scraping Subset #19, Page 23 out of 101 total pages (8.5s)...
#
# Scraping Subset #19, Page 24 out of 101 total pages (9.0s)...
#
# Scraping Subset #19, Page 25 out of 101 total pages (9.2s)...
#
# Scraping Subset #19, Page 26 out of 101 total pages (9.5s)...
#
# Scraping Subset #19, Page 27 out of 101 total pages (8.9s)...
#
# Scraping Subset #19, Page 28 out of 101 total pages (9.3s)...
#
# Scraping Subset #19, Page 29 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 30 out of 101 total pages (10.0s)...
#
# Scraping Subset #19, Page 31 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 32 out of 101 total pages (9.9s)...
#
# Scraping Subset #19, Page 33 out of 101 total pages (9.8s)...
#
# Scraping Subset #19, Page 34 out of 101 total pages (9.4s)...
#
# Scraping Subset #19, Page 35 out of 101 total pages (9.3s)...
#
# Scraping Subset #19, Page 36 out of 101 total pages (7.6s)...
#
# Scraping Subset #19, Page 37 out of 101 total pages (9.5s)...
#
# Scraping Subset #19, Page 38 out of 101 total pages (9.7s)...
#
# Scraping Subset #19, Page 39 out of 101 total pages (9.4s)...
#
# Scraping Subset #19, Page 40 out of 101 total pages (9.9s)...
#
# Scraping Subset #19, Page 41 out of 101 total pages (9.7s)...
#
# Scraping Subset #19, Page 42 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 43 out of 101 total pages (9.9s)...
#
# Scraping Subset #19, Page 44 out of 101 total pages (8.7s)...
#
# Scraping Subset #19, Page 45 out of 101 total pages (9.0s)...
#
# Scraping Subset #19, Page 46 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 47 out of 101 total pages (9.9s)...
#
# Scraping Subset #19, Page 48 out of 101 total pages (10.1s)...
#
# Scraping Subset #19, Page 49 out of 101 total pages (8.8s)...
#
# Scraping Subset #19, Page 50 out of 101 total pages (10.2s)...
#
# Scraping Subset #19, Page 51 out of 101 total pages (8.3s)...
#
# Scraping Subset #19, Page 52 out of 101 total pages (9.8s)...
#
# Scraping Subset #19, Page 53 out of 101 total pages (10.1s)...
#
# Scraping Subset #19, Page 54 out of 101 total pages (11.1s)...
#
# Scraping Subset #19, Page 55 out of 101 total pages (10.8s)...
#
# Scraping Subset #19, Page 56 out of 101 total pages (9.6s)...
#
# Scraping Subset #19, Page 57 out of 101 total pages (9.7s)...
#
# Scraping Subset #19, Page 58 out of 101 total pages (10.6s)...
#
# Scraping Subset #19, Page 59 out of 101 total pages (10.2s)...
#
# Scraping Subset #19, Page 60 out of 101 total pages (9.5s)...
#
# Scraping Subset #19, Page 61 out of 101 total pages (9.6s)...
#
# Scraping Subset #19, Page 62 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 63 out of 101 total pages (9.2s)...
#
# Scraping Subset #19, Page 64 out of 101 total pages (10.7s)...
#
# Scraping Subset #19, Page 65 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 66 out of 101 total pages (9.6s)...
#
# Scraping Subset #19, Page 67 out of 101 total pages (8.4s)...
#
# Scraping Subset #19, Page 68 out of 101 total pages (9.8s)...
#
# Scraping Subset #19, Page 69 out of 101 total pages (8.9s)...
#
# Scraping Subset #19, Page 70 out of 101 total pages (9.9s)...
#
# Scraping Subset #19, Page 71 out of 101 total pages (8.8s)...
#
# Scraping Subset #19, Page 72 out of 101 total pages (7.9s)...
#
# Scraping Subset #19, Page 73 out of 101 total pages (9.6s)...
#
# Scraping Subset #19, Page 74 out of 101 total pages (9.2s)...
#
# Scraping Subset #19, Page 75 out of 101 total pages (7.6s)...
#
# Scraping Subset #19, Page 76 out of 101 total pages (8.5s)...
#
# Scraping Subset #19, Page 77 out of 101 total pages (9.0s)...
#
# Scraping Subset #19, Page 78 out of 101 total pages (9.2s)...
#
# Scraping Subset #19, Page 79 out of 101 total pages (10.1s)...
#
# Scraping Subset #19, Page 80 out of 101 total pages (8.3s)...
#
# Scraping Subset #19, Page 81 out of 101 total pages (8.3s)...
#
# Scraping Subset #19, Page 82 out of 101 total pages (9.9s)...
#
# Scraping Subset #19, Page 83 out of 101 total pages (9.5s)...
#
# Scraping Subset #19, Page 84 out of 101 total pages (9.0s)...
#
# Scraping Subset #19, Page 85 out of 101 total pages (8.8s)...
#
# Scraping Subset #19, Page 86 out of 101 total pages (8.8s)...
#
# Scraping Subset #19, Page 87 out of 101 total pages (8.9s)...
#
# Scraping Subset #19, Page 88 out of 101 total pages (9.5s)...
#
# Scraping Subset #19, Page 89 out of 101 total pages (9.7s)...
#
# Scraping Subset #19, Page 90 out of 101 total pages (10.6s)...
#
# Scraping Subset #19, Page 91 out of 101 total pages (11.9s)...
#
# Scraping Subset #19, Page 92 out of 101 total pages (9.0s)...
#
# Scraping Subset #19, Page 93 out of 101 total pages (8.9s)...
#
# Scraping Subset #19, Page 94 out of 101 total pages (10.3s)...
#
# Scraping Subset #19, Page 95 out of 101 total pages (9.8s)...
#
# Scraping Subset #19, Page 96 out of 101 total pages (8.9s)...
#
# Scraping Subset #19, Page 97 out of 101 total pages (10.0s)...
#
# Scraping Subset #19, Page 98 out of 101 total pages (10.4s)...
#
# Scraping Subset #19, Page 99 out of 101 total pages (9.6s)...
#
# Scraping Subset #19, Page 100 out of 101 total pages (9.1s)...
#
# Scraping Subset #19, Page 101 out of 101 total pages (9.8s)...
#
# No Next Page
#
# Scraping Subset #20, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #20, Page 2 out of 101 total pages (8.7s)...
#
# Scraping Subset #20, Page 3 out of 101 total pages (8.1s)...
#
# Scraping Subset #20, Page 4 out of 101 total pages (7.3s)...
#
# Scraping Subset #20, Page 5 out of 101 total pages (8.1s)...
#
# Scraping Subset #20, Page 6 out of 101 total pages (7.5s)...
#
# Scraping Subset #20, Page 7 out of 101 total pages (9.7s)...
#
# Scraping Subset #20, Page 8 out of 101 total pages (7.5s)...
#
# Scraping Subset #20, Page 9 out of 101 total pages (8.6s)...
#
# Scraping Subset #20, Page 10 out of 101 total pages (8.4s)...
#
# Scraping Subset #20, Page 11 out of 101 total pages (8.2s)...
#
# Scraping Subset #20, Page 12 out of 101 total pages (7.4s)...
#
# Scraping Subset #20, Page 13 out of 101 total pages (7.8s)...
#
# Scraping Subset #20, Page 14 out of 101 total pages (8.2s)...
#
# Scraping Subset #20, Page 15 out of 101 total pages (9.0s)...
#
# Scraping Subset #20, Page 16 out of 101 total pages (8.7s)...
#
# Scraping Subset #20, Page 17 out of 101 total pages (8.7s)...
#
# Scraping Subset #20, Page 18 out of 101 total pages (8.7s)...
#
# Scraping Subset #20, Page 19 out of 101 total pages (8.5s)...
#
# Scraping Subset #20, Page 20 out of 101 total pages (8.8s)...
#
# Scraping Subset #20, Page 21 out of 101 total pages (8.4s)...
#
# Scraping Subset #20, Page 22 out of 101 total pages (7.7s)...
#
# Scraping Subset #20, Page 23 out of 101 total pages (8.9s)...
#
# Scraping Subset #20, Page 24 out of 101 total pages (8.3s)...
#
# Scraping Subset #20, Page 25 out of 101 total pages (8.5s)...
#
# Scraping Subset #20, Page 26 out of 101 total pages (8.8s)...
#
# Scraping Subset #20, Page 27 out of 101 total pages (7.9s)...
#
# Scraping Subset #20, Page 28 out of 101 total pages (8.1s)...
#
# Scraping Subset #20, Page 29 out of 101 total pages (9.5s)...
#
# Scraping Subset #20, Page 30 out of 101 total pages (8.3s)...
#
# Scraping Subset #20, Page 31 out of 101 total pages (9.0s)...
#
# Scraping Subset #20, Page 32 out of 101 total pages (8.5s)...
#
# Scraping Subset #20, Page 33 out of 101 total pages (9.1s)...
#
# Scraping Subset #20, Page 34 out of 101 total pages (9.1s)...
#
# Scraping Subset #20, Page 35 out of 101 total pages (9.0s)...
#
# Scraping Subset #20, Page 36 out of 101 total pages (9.7s)...
#
# Scraping Subset #20, Page 37 out of 101 total pages (8.8s)...
#
# Scraping Subset #20, Page 38 out of 101 total pages (8.3s)...
#
# Scraping Subset #20, Page 39 out of 101 total pages (9.7s)...
#
# Scraping Subset #20, Page 40 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 41 out of 101 total pages (8.5s)...
#
# Scraping Subset #20, Page 42 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 43 out of 101 total pages (10.4s)...
#
# Scraping Subset #20, Page 44 out of 101 total pages (9.0s)...
#
# Scraping Subset #20, Page 45 out of 101 total pages (9.9s)...
#
# Scraping Subset #20, Page 46 out of 101 total pages (9.1s)...
#
# Scraping Subset #20, Page 47 out of 101 total pages (9.8s)...
#
# Scraping Subset #20, Page 48 out of 101 total pages (8.8s)...
#
# Scraping Subset #20, Page 49 out of 101 total pages (9.0s)...
#
# Scraping Subset #20, Page 50 out of 101 total pages (8.8s)...
#
# Scraping Subset #20, Page 51 out of 101 total pages (8.7s)...
#
# Scraping Subset #20, Page 52 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 53 out of 101 total pages (8.3s)...
#
# Scraping Subset #20, Page 54 out of 101 total pages (10.0s)...
#
# Scraping Subset #20, Page 55 out of 101 total pages (9.7s)...
#
# Scraping Subset #20, Page 56 out of 101 total pages (8.0s)...
#
# Scraping Subset #20, Page 57 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 58 out of 101 total pages (9.1s)...
#
# Scraping Subset #20, Page 59 out of 101 total pages (10.9s)...
#
# Scraping Subset #20, Page 60 out of 101 total pages (9.8s)...
#
# Scraping Subset #20, Page 61 out of 101 total pages (8.5s)...
#
# Scraping Subset #20, Page 62 out of 101 total pages (9.8s)...
#
# Scraping Subset #20, Page 63 out of 101 total pages (8.4s)...
#
# Scraping Subset #20, Page 64 out of 101 total pages (8.2s)...
#
# Scraping Subset #20, Page 65 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 66 out of 101 total pages (10.8s)...
#
# Scraping Subset #20, Page 67 out of 101 total pages (10.1s)...
#
# Scraping Subset #20, Page 68 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 69 out of 101 total pages (9.2s)...
#
# Scraping Subset #20, Page 70 out of 101 total pages (10.2s)...
#
# Scraping Subset #20, Page 71 out of 101 total pages (9.2s)...
#
# Scraping Subset #20, Page 72 out of 101 total pages (8.1s)...
#
# Scraping Subset #20, Page 73 out of 101 total pages (9.5s)...
#
# Scraping Subset #20, Page 74 out of 101 total pages (9.5s)...
#
# Scraping Subset #20, Page 75 out of 101 total pages (7.9s)...
#
# Scraping Subset #20, Page 76 out of 101 total pages (10.0s)...
#
# Scraping Subset #20, Page 77 out of 101 total pages (10.8s)...
#
# Scraping Subset #20, Page 78 out of 101 total pages (10.0s)...
#
# Scraping Subset #20, Page 79 out of 101 total pages (9.7s)...
#
# Scraping Subset #20, Page 80 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 81 out of 101 total pages (8.6s)...
#
# Scraping Subset #20, Page 82 out of 101 total pages (9.6s)...
#
# Scraping Subset #20, Page 83 out of 101 total pages (10.8s)...
#
# Scraping Subset #20, Page 84 out of 101 total pages (9.9s)...
#
# Scraping Subset #20, Page 85 out of 101 total pages (9.1s)...
#
# Scraping Subset #20, Page 86 out of 101 total pages (8.9s)...
#
# Scraping Subset #20, Page 87 out of 101 total pages (9.2s)...
#
# Scraping Subset #20, Page 88 out of 101 total pages (9.9s)...
#
# Scraping Subset #20, Page 89 out of 101 total pages (9.4s)...
#
# Scraping Subset #20, Page 90 out of 101 total pages (8.9s)...
#
# Scraping Subset #20, Page 91 out of 101 total pages (8.6s)...
#
# Scraping Subset #20, Page 92 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 93 out of 101 total pages (11.0s)...
#
# Scraping Subset #20, Page 94 out of 101 total pages (12.1s)...
#
# Scraping Subset #20, Page 95 out of 101 total pages (9.1s)...
#
# Scraping Subset #20, Page 96 out of 101 total pages (8.4s)...
#
# Scraping Subset #20, Page 97 out of 101 total pages (10.1s)...
#
# Scraping Subset #20, Page 98 out of 101 total pages (12.4s)...
#
# Scraping Subset #20, Page 99 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 100 out of 101 total pages (9.3s)...
#
# Scraping Subset #20, Page 101 out of 101 total pages (8.6s)...
#
# No Next Page
#
# Scraping Subset #21, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #21, Page 2 out of 101 total pages (7.7s)...
#
# Scraping Subset #21, Page 3 out of 101 total pages (8.5s)...
#
# Scraping Subset #21, Page 4 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 5 out of 101 total pages (8.6s)...
#
# Scraping Subset #21, Page 6 out of 101 total pages (8.8s)...
#
# Scraping Subset #21, Page 7 out of 101 total pages (7.7s)...
#
# Scraping Subset #21, Page 8 out of 101 total pages (8.0s)...
#
# Scraping Subset #21, Page 9 out of 101 total pages (8.5s)...
#
# Scraping Subset #21, Page 10 out of 101 total pages (8.7s)...
#
# Scraping Subset #21, Page 11 out of 101 total pages (8.4s)...
#
# Scraping Subset #21, Page 12 out of 101 total pages (8.3s)...
#
# Scraping Subset #21, Page 13 out of 101 total pages (8.6s)...
#
# Scraping Subset #21, Page 14 out of 101 total pages (7.9s)...
#
# Scraping Subset #21, Page 15 out of 101 total pages (8.2s)...
#
# Scraping Subset #21, Page 16 out of 101 total pages (9.1s)...
#
# Scraping Subset #21, Page 17 out of 101 total pages (8.7s)...
#
# Scraping Subset #21, Page 18 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 19 out of 101 total pages (27.0s)...
#
# Scraping Subset #21, Page 20 out of 101 total pages (8.7s)...
#
# Scraping Subset #21, Page 21 out of 101 total pages (9.2s)...
#
# Scraping Subset #21, Page 22 out of 101 total pages (10.0s)...
#
# Scraping Subset #21, Page 23 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 24 out of 101 total pages (9.0s)...
#
# Scraping Subset #21, Page 25 out of 101 total pages (9.8s)...
#
# Scraping Subset #21, Page 26 out of 101 total pages (7.9s)...
#
# Scraping Subset #21, Page 27 out of 101 total pages (9.6s)...
#
# Scraping Subset #21, Page 28 out of 101 total pages (9.7s)...
#
# Scraping Subset #21, Page 29 out of 101 total pages (9.7s)...
#
# Scraping Subset #21, Page 30 out of 101 total pages (9.1s)...
#
# Scraping Subset #21, Page 31 out of 101 total pages (9.2s)...
#
# Scraping Subset #21, Page 32 out of 101 total pages (10.1s)...
#
# Scraping Subset #21, Page 33 out of 101 total pages (9.2s)...
#
# Scraping Subset #21, Page 34 out of 101 total pages (9.6s)...
#
# Scraping Subset #21, Page 35 out of 101 total pages (9.0s)...
#
# Scraping Subset #21, Page 36 out of 101 total pages (9.5s)...
#
# Scraping Subset #21, Page 37 out of 101 total pages (9.5s)...
#
# Scraping Subset #21, Page 38 out of 101 total pages (8.1s)...
#
# Scraping Subset #21, Page 39 out of 101 total pages (9.3s)...
#
# Scraping Subset #21, Page 40 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 41 out of 101 total pages (8.2s)...
#
# Scraping Subset #21, Page 42 out of 101 total pages (8.8s)...
#
# Scraping Subset #21, Page 43 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 44 out of 101 total pages (9.0s)...
#
# Scraping Subset #21, Page 45 out of 101 total pages (8.8s)...
#
# Scraping Subset #21, Page 46 out of 101 total pages (8.7s)...
#
# Scraping Subset #21, Page 47 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 48 out of 101 total pages (9.2s)...
#
# Scraping Subset #21, Page 49 out of 101 total pages (8.3s)...
#
# Scraping Subset #21, Page 50 out of 101 total pages (8.3s)...
#
# Scraping Subset #21, Page 51 out of 101 total pages (10.9s)...
#
# Scraping Subset #21, Page 52 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 53 out of 101 total pages (9.5s)...
#
# Scraping Subset #21, Page 54 out of 101 total pages (9.0s)...
#
# Scraping Subset #21, Page 55 out of 101 total pages (9.2s)...
#
# Scraping Subset #21, Page 56 out of 101 total pages (9.0s)...
#
# Scraping Subset #21, Page 57 out of 101 total pages (8.9s)...
#
# Scraping Subset #21, Page 58 out of 101 total pages (9.8s)...
#
# Scraping Subset #21, Page 59 out of 101 total pages (8.6s)...
#
# Scraping Subset #21, Page 60 out of 101 total pages (8.2s)...
#
# Scraping Subset #21, Page 61 out of 101 total pages (7.6s)...
#
# Scraping Subset #21, Page 62 out of 101 total pages (9.3s)...
#
# Scraping Subset #21, Page 63 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 64 out of 101 total pages (9.5s)...
#
# Scraping Subset #21, Page 65 out of 101 total pages (9.8s)...
#
# Scraping Subset #21, Page 66 out of 101 total pages (10.5s)...
#
# Scraping Subset #21, Page 67 out of 101 total pages (9.2s)...
#
# Scraping Subset #21, Page 68 out of 101 total pages (9.6s)...
#
# Scraping Subset #21, Page 69 out of 101 total pages (10.2s)...
#
# Scraping Subset #21, Page 70 out of 101 total pages (8.5s)...
#
# Scraping Subset #21, Page 71 out of 101 total pages (9.9s)...
#
# Scraping Subset #21, Page 72 out of 101 total pages (7.9s)...
#
# Scraping Subset #21, Page 73 out of 101 total pages (8.8s)...
#
# Scraping Subset #21, Page 74 out of 101 total pages (7.2s)...
#
# Scraping Subset #21, Page 75 out of 101 total pages (9.3s)...
#
# Scraping Subset #21, Page 76 out of 101 total pages (9.8s)...
#
# Scraping Subset #21, Page 77 out of 101 total pages (10.3s)...
#
# Scraping Subset #21, Page 78 out of 101 total pages (8.9s)...
#
# Scraping Subset #21, Page 79 out of 101 total pages (8.3s)...
#
# Scraping Subset #21, Page 80 out of 101 total pages (9.5s)...
#
# Scraping Subset #21, Page 81 out of 101 total pages (8.7s)...
#
# Scraping Subset #21, Page 82 out of 101 total pages (10.0s)...
#
# Scraping Subset #21, Page 83 out of 101 total pages (8.0s)...
#
# Scraping Subset #21, Page 84 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 85 out of 101 total pages (9.1s)...
#
# Scraping Subset #21, Page 86 out of 101 total pages (7.6s)...
#
# Scraping Subset #21, Page 87 out of 101 total pages (8.7s)...
#
# Scraping Subset #21, Page 88 out of 101 total pages (9.3s)...
#
# Scraping Subset #21, Page 89 out of 101 total pages (10.9s)...
#
# Scraping Subset #21, Page 90 out of 101 total pages (9.9s)...
#
# Scraping Subset #21, Page 91 out of 101 total pages (8.8s)...
#
# Scraping Subset #21, Page 92 out of 101 total pages (9.7s)...
#
# Scraping Subset #21, Page 93 out of 101 total pages (11.3s)...
#
# Scraping Subset #21, Page 94 out of 101 total pages (10.0s)...
#
# Scraping Subset #21, Page 95 out of 101 total pages (9.4s)...
#
# Scraping Subset #21, Page 96 out of 101 total pages (9.7s)...
#
# Scraping Subset #21, Page 97 out of 101 total pages (8.2s)...
#
# Scraping Subset #21, Page 98 out of 101 total pages (8.2s)...
#
# Scraping Subset #21, Page 99 out of 101 total pages (9.5s)...
#
# Scraping Subset #21, Page 100 out of 101 total pages (9.9s)...
#
# Scraping Subset #21, Page 101 out of 101 total pages (10.5s)...
#
# No Next Page
#
# Scraping Subset #22, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #22, Page 2 out of 101 total pages (7.9s)...
#
# Scraping Subset #22, Page 3 out of 101 total pages (8.5s)...
#
# Scraping Subset #22, Page 4 out of 101 total pages (7.7s)...
#
# Scraping Subset #22, Page 5 out of 101 total pages (8.0s)...
#
# Scraping Subset #22, Page 6 out of 101 total pages (7.8s)...
#
# Scraping Subset #22, Page 7 out of 101 total pages (8.7s)...
#
# Scraping Subset #22, Page 8 out of 101 total pages (8.3s)...
#
# Scraping Subset #22, Page 9 out of 101 total pages (8.0s)...
#
# Scraping Subset #22, Page 10 out of 101 total pages (8.6s)...
#
# Scraping Subset #22, Page 11 out of 101 total pages (8.9s)...
#
# Scraping Subset #22, Page 12 out of 101 total pages (7.9s)...
#
# Scraping Subset #22, Page 13 out of 101 total pages (8.1s)...
#
# Scraping Subset #22, Page 14 out of 101 total pages (8.3s)...
#
# Scraping Subset #22, Page 15 out of 101 total pages (9.4s)...
#
# Scraping Subset #22, Page 16 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 17 out of 101 total pages (9.0s)...
#
# Scraping Subset #22, Page 18 out of 101 total pages (8.7s)...
#
# Scraping Subset #22, Page 19 out of 101 total pages (9.7s)...
#
# Scraping Subset #22, Page 20 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 21 out of 101 total pages (8.0s)...
#
# Scraping Subset #22, Page 22 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 23 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 24 out of 101 total pages (8.7s)...
#
# Scraping Subset #22, Page 25 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 26 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 27 out of 101 total pages (8.7s)...
#
# Scraping Subset #22, Page 28 out of 101 total pages (7.9s)...
#
# Scraping Subset #22, Page 29 out of 101 total pages (8.3s)...
#
# Scraping Subset #22, Page 30 out of 101 total pages (10.1s)...
#
# Scraping Subset #22, Page 31 out of 101 total pages (9.3s)...
#
# Scraping Subset #22, Page 32 out of 101 total pages (9.4s)...
#
# Scraping Subset #22, Page 33 out of 101 total pages (8.2s)...
#
# Scraping Subset #22, Page 34 out of 101 total pages (8.0s)...
#
# Scraping Subset #22, Page 35 out of 101 total pages (8.5s)...
#
# Scraping Subset #22, Page 36 out of 101 total pages (10.0s)...
#
# Scraping Subset #22, Page 37 out of 101 total pages (9.3s)...
#
# Scraping Subset #22, Page 38 out of 101 total pages (9.4s)...
#
# Scraping Subset #22, Page 39 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 40 out of 101 total pages (10.2s)...
#
# Scraping Subset #22, Page 41 out of 101 total pages (9.7s)...
#
# Scraping Subset #22, Page 42 out of 101 total pages (8.7s)...
#
# Scraping Subset #22, Page 43 out of 101 total pages (8.2s)...
#
# Scraping Subset #22, Page 44 out of 101 total pages (8.1s)...
#
# Scraping Subset #22, Page 45 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 46 out of 101 total pages (10.2s)...
#
# Scraping Subset #22, Page 47 out of 101 total pages (10.5s)...
#
# Scraping Subset #22, Page 48 out of 101 total pages (8.3s)...
#
# Scraping Subset #22, Page 49 out of 101 total pages (8.8s)...
#
# Scraping Subset #22, Page 50 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 51 out of 101 total pages (9.8s)...
#
# Scraping Subset #22, Page 52 out of 101 total pages (9.3s)...
#
# Scraping Subset #22, Page 53 out of 101 total pages (9.5s)...
#
# Scraping Subset #22, Page 54 out of 101 total pages (9.3s)...
#
# Scraping Subset #22, Page 55 out of 101 total pages (7.9s)...
#
# Scraping Subset #22, Page 56 out of 101 total pages (8.9s)...
#
# Scraping Subset #22, Page 57 out of 101 total pages (7.8s)...
#
# Scraping Subset #22, Page 58 out of 101 total pages (10.0s)...
#
# Scraping Subset #22, Page 59 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 60 out of 101 total pages (9.8s)...
#
# Scraping Subset #22, Page 61 out of 101 total pages (9.6s)...
#
# Scraping Subset #22, Page 62 out of 101 total pages (8.0s)...
#
# Scraping Subset #22, Page 63 out of 101 total pages (10.5s)...
#
# Scraping Subset #22, Page 64 out of 101 total pages (9.0s)...
#
# Scraping Subset #22, Page 65 out of 101 total pages (10.3s)...
#
# Scraping Subset #22, Page 66 out of 101 total pages (9.9s)...
#
# Scraping Subset #22, Page 67 out of 101 total pages (8.6s)...
#
# Scraping Subset #22, Page 68 out of 101 total pages (9.0s)...
#
# Scraping Subset #22, Page 69 out of 101 total pages (8.9s)...
#
# Scraping Subset #22, Page 70 out of 101 total pages (9.6s)...
#
# Scraping Subset #22, Page 71 out of 101 total pages (9.7s)...
#
# Scraping Subset #22, Page 72 out of 101 total pages (8.3s)...
#
# Scraping Subset #22, Page 73 out of 101 total pages (9.0s)...
#
# Scraping Subset #22, Page 74 out of 101 total pages (10.3s)...
#
# Scraping Subset #22, Page 75 out of 101 total pages (9.8s)...
#
# Scraping Subset #22, Page 76 out of 101 total pages (8.6s)...
#
# Scraping Subset #22, Page 77 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 78 out of 101 total pages (9.8s)...
#
# Scraping Subset #22, Page 79 out of 101 total pages (10.3s)...
#
# Scraping Subset #22, Page 80 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 81 out of 101 total pages (8.1s)...
#
# Scraping Subset #22, Page 82 out of 101 total pages (9.6s)...
#
# Scraping Subset #22, Page 83 out of 101 total pages (10.5s)...
#
# Scraping Subset #22, Page 84 out of 101 total pages (10.6s)...
#
# Scraping Subset #22, Page 85 out of 101 total pages (8.8s)...
#
# Scraping Subset #22, Page 86 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 87 out of 101 total pages (8.9s)...
#
# Scraping Subset #22, Page 88 out of 101 total pages (9.0s)...
#
# Scraping Subset #22, Page 89 out of 101 total pages (10.5s)...
#
# Scraping Subset #22, Page 90 out of 101 total pages (8.4s)...
#
# Scraping Subset #22, Page 91 out of 101 total pages (8.1s)...
#
# Scraping Subset #22, Page 92 out of 101 total pages (9.4s)...
#
# Scraping Subset #22, Page 93 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 94 out of 101 total pages (9.7s)...
#
# Scraping Subset #22, Page 95 out of 101 total pages (9.1s)...
#
# Scraping Subset #22, Page 96 out of 101 total pages (9.2s)...
#
# Scraping Subset #22, Page 97 out of 101 total pages (8.8s)...
#
# Scraping Subset #22, Page 98 out of 101 total pages (10.1s)...
#
# Scraping Subset #22, Page 99 out of 101 total pages (10.9s)...
#
# Scraping Subset #22, Page 100 out of 101 total pages (8.7s)...
#
# Scraping Subset #22, Page 101 out of 101 total pages (9.3s)...
#
# No Next Page
#
# Scraping Subset #23, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #23, Page 2 out of 101 total pages (7.3s)...
#
# Scraping Subset #23, Page 3 out of 101 total pages (8.6s)...
#
# Scraping Subset #23, Page 4 out of 101 total pages (8.5s)...
#
# Scraping Subset #23, Page 5 out of 101 total pages (9.0s)...
#
# Scraping Subset #23, Page 6 out of 101 total pages (7.4s)...
#
# Scraping Subset #23, Page 7 out of 101 total pages (8.0s)...
#
# Scraping Subset #23, Page 8 out of 101 total pages (9.0s)...
#
# Scraping Subset #23, Page 9 out of 101 total pages (8.5s)...
#
# Scraping Subset #23, Page 10 out of 101 total pages (8.7s)...
#
# Scraping Subset #23, Page 11 out of 101 total pages (8.4s)...
#
# Scraping Subset #23, Page 12 out of 101 total pages (8.6s)...
#
# Scraping Subset #23, Page 13 out of 101 total pages (8.5s)...
#
# Scraping Subset #23, Page 14 out of 101 total pages (8.9s)...
#
# Scraping Subset #23, Page 15 out of 101 total pages (7.3s)...
#
# Scraping Subset #23, Page 16 out of 101 total pages (9.0s)...
#
# Scraping Subset #23, Page 17 out of 101 total pages (8.9s)...
#
# Scraping Subset #23, Page 18 out of 101 total pages (9.1s)...
#
# Scraping Subset #23, Page 19 out of 101 total pages (8.4s)...
#
# Scraping Subset #23, Page 20 out of 101 total pages (10.0s)...
#
# Scraping Subset #23, Page 21 out of 101 total pages (9.6s)...
#
# Scraping Subset #23, Page 22 out of 101 total pages (8.9s)...
#
# Scraping Subset #23, Page 23 out of 101 total pages (8.7s)...
#
# Scraping Subset #23, Page 24 out of 101 total pages (8.7s)...
#
# Scraping Subset #23, Page 25 out of 101 total pages (8.8s)...
#
# Scraping Subset #23, Page 26 out of 101 total pages (9.3s)...
#
# Scraping Subset #23, Page 27 out of 101 total pages (8.8s)...
#
# Scraping Subset #23, Page 28 out of 101 total pages (9.1s)...
#
# Scraping Subset #23, Page 29 out of 101 total pages (8.0s)...
#
# Scraping Subset #23, Page 30 out of 101 total pages (8.4s)...
#
# Scraping Subset #23, Page 31 out of 101 total pages (9.1s)...
#
# Scraping Subset #23, Page 32 out of 101 total pages (8.4s)...
#
# Scraping Subset #23, Page 33 out of 101 total pages (8.1s)...
#
# Scraping Subset #23, Page 34 out of 101 total pages (7.8s)...
#
# Scraping Subset #23, Page 35 out of 101 total pages (8.3s)...
#
# Scraping Subset #23, Page 36 out of 101 total pages (9.3s)...
#
# Scraping Subset #23, Page 37 out of 101 total pages (9.6s)...
#
# Scraping Subset #23, Page 38 out of 101 total pages (8.9s)...
#
# Scraping Subset #23, Page 39 out of 101 total pages (9.7s)...
#
# Scraping Subset #23, Page 40 out of 101 total pages (10.3s)...
#
# Scraping Subset #23, Page 41 out of 101 total pages (9.7s)...
#
# Scraping Subset #23, Page 42 out of 101 total pages (10.2s)...
#
# Scraping Subset #23, Page 43 out of 101 total pages (10.5s)...
#
# Scraping Subset #23, Page 44 out of 101 total pages (9.6s)...
#
# Scraping Subset #23, Page 45 out of 101 total pages (9.2s)...
#
# Scraping Subset #23, Page 46 out of 101 total pages (8.4s)...
#
# Scraping Subset #23, Page 47 out of 101 total pages (9.3s)...
#
# Scraping Subset #23, Page 48 out of 101 total pages (9.7s)...
#
# Scraping Subset #23, Page 49 out of 101 total pages (9.1s)...
#
# Scraping Subset #23, Page 50 out of 101 total pages (10.4s)...
#
# Scraping Subset #23, Page 51 out of 101 total pages (8.9s)...
#
# Scraping Subset #23, Page 52 out of 101 total pages (9.6s)...
#
# ...
#
# Scraping Subset #27, Page 42 out of 101 total pages (8.2s)...
#
# Scraping Subset #27, Page 43 out of 101 total pages (8.8s)...
#
# Scraping Subset #27, Page 44 out of 101 total pages (9.2s)...
#
# Scraping Subset #27, Page 45 out of 101 total pages (8.5s)...
#
# Scraping Subset #27, Page 46 out of 101 total pages (8.6s)...
#
# Scraping Subset #27, Page 47 out of 101 total pages (9.5s)...
#
# Scraping Subset #27, Page 48 out of 101 total pages (9.6s)...
#
# Scraping Subset #27, Page 49 out of 101 total pages (8.5s)...
#
# Scraping Subset #27, Page 50 out of 101 total pages (8.6s)...
#
# Scraping Subset #27, Page 51 out of 101 total pages (9.2s)...
#
# Scraping Subset #27, Page 52 out of 101 total pages (9.4s)...
#
# Scraping Subset #27, Page 53 out of 101 total pages (8.8s)...
#
# Scraping Subset #27, Page 54 out of 101 total pages (9.3s)...
#
# Scraping Subset #27, Page 55 out of 101 total pages (9.4s)...
#
# Scraping Subset #27, Page 56 out of 101 total pages (10.3s)...
#
# Scraping Subset #27, Page 57 out of 101 total pages (10.1s)...
#
# Scraping Subset #27, Page 58 out of 101 total pages (9.4s)...
#
# Scraping Subset #27, Page 59 out of 101 total pages (9.2s)...
#
# Scraping Subset #27, Page 60 out of 101 total pages (9.6s)...
#
# Scraping Subset #27, Page 61 out of 101 total pages (9.4s)...
#
# Scraping Subset #27, Page 62 out of 101 total pages (9.3s)...
#
# Scraping Subset #27, Page 63 out of 101 total pages (10.2s)...
#
# Scraping Subset #27, Page 64 out of 101 total pages (9.3s)...
#
# Scraping Subset #27, Page 65 out of 101 total pages (9.5s)...
#
# Scraping Subset #27, Page 66 out of 101 total pages (9.6s)...
#
# Scraping Subset #27, Page 67 out of 101 total pages (8.3s)...
#
# Scraping Subset #27, Page 68 out of 101 total pages (8.1s)...
#
# Scraping Subset #27, Page 69 out of 101 total pages (10.0s)...
#
# Scraping Subset #27, Page 70 out of 101 total pages (8.1s)...
#
# Scraping Subset #27, Page 71 out of 101 total pages (9.7s)...
#
# Scraping Subset #27, Page 72 out of 101 total pages (9.9s)...
#
# Scraping Subset #27, Page 73 out of 101 total pages (9.1s)...
#
# Scraping Subset #27, Page 74 out of 101 total pages (7.8s)...
#
# Scraping Subset #27, Page 75 out of 101 total pages (9.3s)...
#
# Scraping Subset #27, Page 76 out of 101 total pages (8.4s)...
#
# Scraping Subset #27, Page 77 out of 101 total pages (8.3s)...
#
# Scraping Subset #27, Page 78 out of 101 total pages (9.1s)...
#
# Scraping Subset #27, Page 79 out of 101 total pages (8.9s)...
#
# Scraping Subset #27, Page 80 out of 101 total pages (9.2s)...
#
# Scraping Subset #27, Page 81 out of 101 total pages (9.0s)...
#
# Scraping Subset #27, Page 82 out of 101 total pages (9.2s)...
#
# Scraping Subset #27, Page 83 out of 101 total pages (9.1s)...
#
# Scraping Subset #27, Page 84 out of 101 total pages (10.1s)...
#
# Scraping Subset #27, Page 85 out of 101 total pages (8.7s)...
#
# Scraping Subset #27, Page 86 out of 101 total pages (9.6s)...
#
# Scraping Subset #27, Page 87 out of 101 total pages (9.9s)...
#
# Scraping Subset #27, Page 88 out of 101 total pages (11.0s)...
#
# Scraping Subset #27, Page 89 out of 101 total pages (10.5s)...
#
# Scraping Subset #27, Page 90 out of 101 total pages (10.3s)...
#
# Scraping Subset #27, Page 91 out of 101 total pages (8.5s)...
#
# Scraping Subset #27, Page 92 out of 101 total pages (8.5s)...
#
# Scraping Subset #27, Page 93 out of 101 total pages (9.2s)...
#
# Scraping Subset #27, Page 94 out of 101 total pages (9.0s)...
#
# Scraping Subset #27, Page 95 out of 101 total pages (10.5s)...
#
# Scraping Subset #27, Page 96 out of 101 total pages (9.7s)...
#
# Scraping Subset #27, Page 97 out of 101 total pages (9.7s)...
#
# Scraping Subset #27, Page 98 out of 101 total pages (9.3s)...
#
# Scraping Subset #27, Page 99 out of 101 total pages (8.8s)...
#
# Scraping Subset #27, Page 100 out of 101 total pages (10.7s)...
#
# Scraping Subset #27, Page 101 out of 101 total pages (11.6s)...
#
# No Next Page
#
# Scraping Subset #28, Page 1 out of 101 total pages (0s)...
#
# Scraping Subset #28, Page 2 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 3 out of 101 total pages (7.4s)...
#
# Scraping Subset #28, Page 4 out of 101 total pages (7.3s)...
#
# Scraping Subset #28, Page 5 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 6 out of 101 total pages (8.1s)...
#
# Scraping Subset #28, Page 7 out of 101 total pages (8.4s)...
#
# Scraping Subset #28, Page 8 out of 101 total pages (9.2s)...
#
# Scraping Subset #28, Page 9 out of 101 total pages (8.1s)...
#
# Scraping Subset #28, Page 10 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 11 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 12 out of 101 total pages (7.8s)...
#
# Scraping Subset #28, Page 13 out of 101 total pages (9.6s)...
#
# Scraping Subset #28, Page 14 out of 101 total pages (8.8s)...
#
# Scraping Subset #28, Page 15 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 16 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 17 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 18 out of 101 total pages (8.5s)...
#
# Scraping Subset #28, Page 19 out of 101 total pages (9.7s)...
#
# Scraping Subset #28, Page 20 out of 101 total pages (8.7s)...
#
# Scraping Subset #28, Page 21 out of 101 total pages (9.4s)...
#
# Scraping Subset #28, Page 22 out of 101 total pages (9.6s)...
#
# Scraping Subset #28, Page 23 out of 101 total pages (7.6s)...
#
# Scraping Subset #28, Page 24 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 25 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 26 out of 101 total pages (8.6s)...
#
# Scraping Subset #28, Page 27 out of 101 total pages (9.2s)...
#
# Scraping Subset #28, Page 28 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 29 out of 101 total pages (8.8s)...
#
# Scraping Subset #28, Page 30 out of 101 total pages (8.7s)...
#
# Scraping Subset #28, Page 31 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 32 out of 101 total pages (8.5s)...
#
# Scraping Subset #28, Page 33 out of 101 total pages (9.6s)...
#
# Scraping Subset #28, Page 34 out of 101 total pages (9.4s)...
#
# Scraping Subset #28, Page 35 out of 101 total pages (9.5s)...
#
# Scraping Subset #28, Page 36 out of 101 total pages (10.2s)...
#
# Scraping Subset #28, Page 37 out of 101 total pages (10.0s)...
#
# Scraping Subset #28, Page 38 out of 101 total pages (8.6s)...
#
# Scraping Subset #28, Page 39 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 40 out of 101 total pages (8.4s)...
#
# Scraping Subset #28, Page 41 out of 101 total pages (9.5s)...
#
# Scraping Subset #28, Page 42 out of 101 total pages (8.7s)...
#
# Scraping Subset #28, Page 43 out of 101 total pages (8.5s)...
#
# Scraping Subset #28, Page 44 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 45 out of 101 total pages (8.5s)...
#
# Scraping Subset #28, Page 46 out of 101 total pages (9.9s)...
#
# Scraping Subset #28, Page 47 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 48 out of 101 total pages (9.6s)...
#
# Scraping Subset #28, Page 49 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 50 out of 101 total pages (10.1s)...
#
# Scraping Subset #28, Page 51 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 52 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 53 out of 101 total pages (9.0s)...
#
# Scraping Subset #28, Page 54 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 55 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 56 out of 101 total pages (9.9s)...
#
# Scraping Subset #28, Page 57 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 58 out of 101 total pages (10.2s)...
#
# Scraping Subset #28, Page 59 out of 101 total pages (10.5s)...
#
# Scraping Subset #28, Page 60 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 61 out of 101 total pages (9.4s)...
#
# Scraping Subset #28, Page 62 out of 101 total pages (9.5s)...
#
# Scraping Subset #28, Page 63 out of 101 total pages (9.4s)...
#
# Scraping Subset #28, Page 64 out of 101 total pages (9.8s)...
#
# Scraping Subset #28, Page 65 out of 101 total pages (9.5s)...
#
# Scraping Subset #28, Page 66 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 67 out of 101 total pages (9.9s)...
#
# Scraping Subset #28, Page 68 out of 101 total pages (9.8s)...
#
# Scraping Subset #28, Page 69 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 70 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 71 out of 101 total pages (9.6s)...
#
# Scraping Subset #28, Page 72 out of 101 total pages (9.9s)...
#
# Scraping Subset #28, Page 73 out of 101 total pages (9.2s)...
#
# Scraping Subset #28, Page 74 out of 101 total pages (8.3s)...
#
# Scraping Subset #28, Page 75 out of 101 total pages (8.5s)...
#
# Scraping Subset #28, Page 76 out of 101 total pages (9.8s)...
#
# Scraping Subset #28, Page 77 out of 101 total pages (9.7s)...
#
# Scraping Subset #28, Page 78 out of 101 total pages (8.1s)...
#
# Scraping Subset #28, Page 79 out of 101 total pages (8.1s)...
#
# Scraping Subset #28, Page 80 out of 101 total pages (8.3s)...
#
# Scraping Subset #28, Page 81 out of 101 total pages (8.9s)...
#
# Scraping Subset #28, Page 82 out of 101 total pages (10.4s)...
#
# Scraping Subset #28, Page 83 out of 101 total pages (10.0s)...
#
# Scraping Subset #28, Page 84 out of 101 total pages (8.4s)...
#
# Scraping Subset #28, Page 85 out of 101 total pages (10.2s)...
#
# Scraping Subset #28, Page 86 out of 101 total pages (9.5s)...
#
# Scraping Subset #28, Page 87 out of 101 total pages (9.5s)...
#
# Scraping Subset #28, Page 88 out of 101 total pages (9.7s)...
#
# Scraping Subset #28, Page 89 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 90 out of 101 total pages (9.3s)...
#
# Scraping Subset #28, Page 91 out of 101 total pages (7.3s)...
#
# Scraping Subset #28, Page 92 out of 101 total pages (9.1s)...
#
# Scraping Subset #28, Page 93 out of 101 total pages (10.2s)...
#
# Scraping Subset #28, Page 94 out of 101 total pages (8.8s)...
#
# Scraping Subset #28, Page 95 out of 101 total pages (9.7s)...
#
# Scraping Subset #28, Page 96 out of 101 total pages (10.9s)...
#
# Scraping Subset #28, Page 97 out of 101 total pages (8.0s)...
#
# Scraping Subset #28, Page 98 out of 101 total pages (8.5s)...
#
# Scraping Subset #28, Page 99 out of 101 total pages (9.0s)...
#
# Scraping Subset #28, Page 100 out of 101 total pages (9.2s)...
#
# Scraping Subset #28, Page 101 out of 101 total pages (10.3s)...
#
# No Next Page
#
# Scraping Subset #29, Page 1 out of 75 total pages (0s)...
#
# Scraping Subset #29, Page 2 out of 75 total pages (8.5s)...
#
# Scraping Subset #29, Page 3 out of 75 total pages (7.9s)...
#
# Scraping Subset #29, Page 4 out of 75 total pages (8.7s)...
#
# Scraping Subset #29, Page 5 out of 75 total pages (7.5s)...
#
# Scraping Subset #29, Page 6 out of 75 total pages (9.3s)...
#
# Scraping Subset #29, Page 7 out of 75 total pages (7.7s)...
#
# Scraping Subset #29, Page 8 out of 75 total pages (8.4s)...
#
# Scraping Subset #29, Page 9 out of 75 total pages (8.0s)...
#
# Scraping Subset #29, Page 10 out of 75 total pages (7.9s)...
#
# Scraping Subset #29, Page 11 out of 75 total pages (9.6s)...
#
# Scraping Subset #29, Page 12 out of 75 total pages (8.0s)...
#
# Scraping Subset #29, Page 13 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 14 out of 75 total pages (8.3s)...
#
# Scraping Subset #29, Page 15 out of 75 total pages (8.7s)...
#
# Scraping Subset #29, Page 16 out of 75 total pages (8.1s)...
#
# Scraping Subset #29, Page 17 out of 75 total pages (8.8s)...
#
# Scraping Subset #29, Page 18 out of 75 total pages (8.3s)...
#
# Scraping Subset #29, Page 19 out of 75 total pages (8.4s)...
#
# Scraping Subset #29, Page 20 out of 75 total pages (8.5s)...
#
# Scraping Subset #29, Page 21 out of 75 total pages (8.8s)...
#
# Scraping Subset #29, Page 22 out of 75 total pages (8.2s)...
#
# Scraping Subset #29, Page 23 out of 75 total pages (8.7s)...
#
# Scraping Subset #29, Page 24 out of 75 total pages (9.2s)...
#
# Scraping Subset #29, Page 25 out of 75 total pages (8.8s)...
#
# Scraping Subset #29, Page 26 out of 75 total pages (7.8s)...
#
# Scraping Subset #29, Page 27 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 28 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 29 out of 75 total pages (9.9s)...
#
# Scraping Subset #29, Page 30 out of 75 total pages (8.9s)...
#
# Scraping Subset #29, Page 31 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 32 out of 75 total pages (9.4s)...
#
# Scraping Subset #29, Page 33 out of 75 total pages (8.6s)...
#
# Scraping Subset #29, Page 34 out of 75 total pages (9.2s)...
#
# Scraping Subset #29, Page 35 out of 75 total pages (8.6s)...
#
# Scraping Subset #29, Page 36 out of 75 total pages (8.9s)...
#
# Scraping Subset #29, Page 37 out of 75 total pages (8.6s)...
#
# Scraping Subset #29, Page 38 out of 75 total pages (8.2s)...
#
# Scraping Subset #29, Page 39 out of 75 total pages (10.5s)...
#
# Scraping Subset #29, Page 40 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 41 out of 75 total pages (8.7s)...
#
# Scraping Subset #29, Page 42 out of 75 total pages (9.4s)...
#
# Scraping Subset #29, Page 43 out of 75 total pages (9.0s)...
#
# Scraping Subset #29, Page 44 out of 75 total pages (10.5s)...
#
# Scraping Subset #29, Page 45 out of 75 total pages (8.5s)...
#
# Scraping Subset #29, Page 46 out of 75 total pages (9.6s)...
#
# Scraping Subset #29, Page 47 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 48 out of 75 total pages (9.3s)...
#
# Scraping Subset #29, Page 49 out of 75 total pages (8.9s)...
#
# Scraping Subset #29, Page 50 out of 75 total pages (9.0s)...
#
# Scraping Subset #29, Page 51 out of 75 total pages (10.2s)...
#
# Scraping Subset #29, Page 52 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 53 out of 75 total pages (10.2s)...
#
# Scraping Subset #29, Page 54 out of 75 total pages (9.6s)...
#
# Scraping Subset #29, Page 55 out of 75 total pages (9.9s)...
#
# Scraping Subset #29, Page 56 out of 75 total pages (9.6s)...
#
# Scraping Subset #29, Page 57 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 58 out of 75 total pages (9.8s)...
#
# Scraping Subset #29, Page 59 out of 75 total pages (9.4s)...
#
# Scraping Subset #29, Page 60 out of 75 total pages (9.7s)...
#
# Scraping Subset #29, Page 61 out of 75 total pages (8.5s)...
#
# Scraping Subset #29, Page 62 out of 75 total pages (9.8s)...
#
# Scraping Subset #29, Page 63 out of 75 total pages (10.8s)...
#
# Scraping Subset #29, Page 64 out of 75 total pages (9.5s)...
#
# Scraping Subset #29, Page 65 out of 75 total pages (8.5s)...
#
# Scraping Subset #29, Page 66 out of 75 total pages (9.6s)...
#
# Scraping Subset #29, Page 67 out of 75 total pages (9.4s)...
#
# Scraping Subset #29, Page 68 out of 75 total pages (10.7s)...
#
# Scraping Subset #29, Page 69 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 70 out of 75 total pages (9.1s)...
#
# Scraping Subset #29, Page 71 out of 75 total pages (9.5s)...
#
# Scraping Subset #29, Page 72 out of 75 total pages (8.9s)...
#
# Scraping Subset #29, Page 73 out of 75 total pages (9.2s)...
#
# Scraping Subset #29, Page 74 out of 75 total pages (10.3s)...
#
# Scraping Subset #29, Page 75 out of 75 total pages (9.0s)...
#
# No Next Page
#
# Scraping Subset #30, Page 1 out of -25 total pages (0s)...
# Error... Moving On
# Message: no such element: Unable to locate element: {"method":"tag name","selector":"div"}
#   (Session info: chrome=134.0.6998.118); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x011FC7F3+24435]
# 	(No symbol) [0x01182074]
# 	(No symbol) [0x010506E3]
# 	(No symbol) [0x01098B39]
# 	(No symbol) [0x01098E8B]
# 	(No symbol) [0x0108E1F1]
# 	(No symbol) [0x010BD804]
# 	(No symbol) [0x0108E114]
# 	(No symbol) [0x010BDA34]
# 	(No symbol) [0x010DF20A]
# 	(No symbol) [0x010BD5B6]
# 	(No symbol) [0x0108C54F]
# 	(No symbol) [0x0108D894]
# 	GetHandleVerifier [0x015070A3+3213347]
# 	GetHandleVerifier [0x0151B0C9+3295305]
# 	GetHandleVerifier [0x0151558C+3271948]
# 	GetHandleVerifier [0x01297360+658144]
# 	(No symbol) [0x0118B27D]
# 	(No symbol) [0x01188208]
# 	(No symbol) [0x011883A9]
# 	(No symbol) [0x0117AAC0]
# 	BaseThreadInitThunk [0x7701FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x779C82AE+286]
# 	RtlGetAppContainerNamedObjectPath [0x779C827E+238]
#
#
# No Next Page
